# %% [markdown]
# # Setup

# %% [markdown]
# ### Import Dependencies

# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup as bs
import re
import requests
import time
import pandas as pd
import unicodedata
import random

# %% [markdown]
# ### Set URLs

# %%
# base URL for race results
base_url = "https://results.nyrr.org/event/"

# specific races

race_code = "M2019" # 2019 NYC Marathon. includes gun time and splits

# race_code = "20WH5K" # 2020 Washington Heights 5K. 4942 finishers. yes to gun time, no to splits

# race_code = "a70414" # 2007 Brooklyn Half. 4853 finishers. no gun time, no splits

# race_code = "19nyc60" # 2019 NYC 60K. 375 finishers, gun time, no splits

# race_code = "1860k" # 2018 NYC 60K. 360 finishers, gun time, no splits

# race_code = "1760K" # 2017 NYC 60K. 358 finishers (plus one handcycle), gun time, no splits

# race_code = "60K16" # 2016 NYC 60K. 366 finishers, gun time, no splits. 2 runners do not have an address.

race_url = base_url + race_code + "/result/"

# %% [markdown]
# ### Set File Locations

# %%
# Set path for chromedriver
executable_path = {'chromedriver.exe'}

# set paths for outputs
output_csv_path = "../00_data/raw_data/"
output_csv_name_base = "finishers"

log_csv_path = "../00_data/raw_data/"
log_csv_name_base = "scraping_log"

# %% [markdown]
# ### Set Scraping Parameters

# %%
# lowest bib number in scraping range
low_bib = 72001

# highest bib number in scraping range
high_bib = 75000

# add any additional targets
additional_scraping_targets = []

# %% [markdown]
# # Scraping

# %% [markdown]
# ### Define scraping function

# %%
def finisher_scraper(soup):
    finisher_dict = {}
# block 1
    thangs = soup.find(class_='cursor-pointer results-link').findChildren()
    finisher_dict['name'] = thangs[0].text
    
    # The address is presented as a subregion, then a pipe "|", then a country code.
    # For US addresses, the subregion is presented as town followed by state abbreviation.
    # Some runners don't have a full address listed, so carefully parse out what is there.
    # Assume that the most basic information would be the runner's country (i.e. country of residence).
    # Note that these are ISO 3166-1 country codes, e.g. Germany = 'DEU'.
    # These items do not have labels (e.g. 'country') associated with them, so
    # the keys are hardcoded here.
    
    if '|' in thangs[1].text:
        finisher_dict['geo_subregion'] = thangs[1].text.split('|')[0].strip()
        finisher_dict['country'] = thangs[1].text.split('|')[1].strip()
    else:
        finisher_dict['country'] = thangs[1].text.strip()
    
    for thing in soup.find_all('strong'):
        if thing.next_sibling:
            
            #look for gender and age, and record those separately.
            
            pattern = re.compile('[MF][1-9][0-9]?')
            if pattern.match(thing.next_sibling.strip()):
                finisher_dict['gender'] = thing.next_sibling.strip()[0]
                finisher_dict['age'] = thing.next_sibling.strip()[1:]
                continue
                
            # I prefer the keys and columns be lowercase without spaces, so make those changes
            # while reading in the keys.
            
            finisher_dict[thing.text.strip().lower().replace(" ", "_").replace("/", "_and_")] = thing.next_sibling.strip()
            
# block 2 and block 3
    regex = re.compile('.*form-group-item.*')
#     block_2_soup = soup.find_all("div", {"class" : regex})[:4] # this gets only block 2
    block_2_soup = soup.find_all("div", {"class" : regex}) # this gets block 3 as well
    for spoonful in block_2_soup:
        
        # The data found here can vary from race to race and runner to runner. These items have labels
        # associated with them. To be flexible, we read the label itself and use it as the dict key.
        # Not every runner will have a full set of label-value pairs, and the pair vary from race to race.
        # For example, a runner's bib might not get recorded at a particular checkpoint, and a half marathon
        # would not have as many checkpoints as a marathon.
        
        labels = spoonful.find_all('label')
        values = spoonful.find_all('span', {'class': 'label-value ng-binding'})
        
        # Step through all the labels and add each key(label)-value pair to the dict.
        
        for x in range(0, len(labels)):
            
            # there was a '\xa0' coming in as part of the 'Place Country' label
            # use unicodedata.normalize to replace that with a space.
            
            label = unicodedata.normalize("NFKD", labels[x].text)
            
            # if we find the place in age-group, add the age group to the dictionary.
            
            if label.endswith("Place Age‐Group"):
                finisher_dict["age_group"] = re.findall(r'\(([^]]*)\)', label)[0]
                label = "Place Age-Group"
                
            # If we find the place in country, add the country group (i.e. country of citizenship) to the dictionary.
            # Note that this is not necessarily the same as the runner's address.
            # This country code is in IOC format, e.g. Germany = 'GER'.
                
            elif label.endswith("Place Country"):
                finisher_dict["country_group"] = re.findall(r'\(([^]]*)\)', label)[0]
                label = "Place Country"
                
            # Add pairs to dict. Make sure keys are lowecase without spaces.
            
            finisher_dict[label.strip().lower().replace(" ", "_")] = values[x].text


    return finisher_dict

# %%
def scraping_loop(race_url, scrape_list):
    
    # These lists will be returned.
    finishers = []
    dnf_list = []
    scraping_log = []
    error_list = []

    # These counters are used for reporting progress.
    attempt_counter = 0
    hit_counter = 0
    miss_counter = 0
    error_counter = 0
    
    browser = Browser('chrome', headless=False)

    for bib_number in scrape_list:
        url = race_url + str(bib_number)
        browser.visit(url)
        # We need a short sleep period to give the site a chance to redirect an invalid bib number.
        # We also don't need to beat on the website too hard.
        time.sleep(3)
    #     time.sleep(random.uniform(3,7))
        attempt_counter += 1
        
        # If the url does not redirect, then the bib number crossed the finish line. Scrape it.
        if browser.url == url:
            try:
                soup = bs(browser.html, "html.parser")
                new_result = finisher_scraper(soup)

                # We're being intentionally flexible about what data we gather, 
                # but bib number and finish time are the bare minimum.
                # Check to see if there is a bib number and official finish time included in the finisher_dict.
                if (new_result.get('bib') and new_result.get('name')):
                    finishers.append(new_result)
                    scraping_log.append({'bib': bib_number, 'outcome': 'success'})
                    hit_counter += 1
                    
                # If the url was good, but bib number and official time are missing, then something went wrong during
                # scraping. Log it as an error.
                else:
                    scraping_log.append({'bib': bib_number, 'outcome': 'error'})
                    error_list.append(bib_number)
                    error_counter += 1

            # If bs can't even parse the page, something went wrong. Log it as an error.
            except:
                scraping_log.append({'bib': bib_number, 'outcome': 'error'})
                error_list.append(bib_number)
                error_counter += 1
        
        # If the url resulted in a redirect, then that bib number never crossed the finish line. Log it as DNF.
        # Note that the bib may never have been issued, or the runner may have dropped out 50m from the finish.
        # All we know is that the bib was not logged as a finisher.
        else:
            scraping_log.append({'bib': bib_number, 'outcome': 'DNF'})
            dnf_list.append(bib_number)
            miss_counter += 1
        
        # Report running totals of the scraping progress.
        print(f"Attempted {attempt_counter} of {len(scrape_list)}: Found {hit_counter} finishers ({(hit_counter/attempt_counter):.2%}), {miss_counter} DNFs, and {error_counter} errors.")
    
    print('Loop complete')
    print(f"{attempt_counter} attempts yielded {hit_counter} hits ({(hit_counter/attempt_counter):.2%}) with {error_counter} errors.")
    browser.quit()
    
    return [finishers, dnf_list, error_list, scraping_log]

# %% [markdown]
# ### Scraping Loop

# %%
# Build the list of bibs to scrape.
scrape_list = list(range(low_bib,high_bib+1))

# Add in any additional scraping targets, if applicable.
scrape_list.extend(additional_scraping_targets)
    
# Shuffle the list. This helps us to get an ide of the 'richness' of the specified bib range is after a few dozen scrapes.
random.shuffle(scrape_list)

# %%
# scrape through the list
scrape_results = scraping_loop(race_url, scrape_list)
runners = scrape_results[0]
scraping_log = scrape_results[3]

# Go back and retry any bibs that didn't load on the first try.
if scrape_results[2]:
    error_list = scrape_results[2]
    second_scrape = scraping_loop(race_url, error_list)
    runners.extend(second_scrape[0])
    scraping_log.extend(second_scrape[3])
# Out:
# Attempted 1 of 3000: Found 1 finishers (100.00%), 0 DNFs, and 0 errors.
# Attempted 2 of 3000: Found 1 finishers (50.00%), 1 DNFs, and 0 errors.
# Attempted 3 of 3000: Found 2 finishers (66.67%), 1 DNFs, and 0 errors.
# Attempted 4 of 3000: Found 2 finishers (50.00%), 2 DNFs, and 0 errors.
# Attempted 5 of 3000: Found 2 finishers (40.00%), 3 DNFs, and 0 errors.
# Attempted 6 of 3000: Found 2 finishers (33.33%), 4 DNFs, and 0 errors.
# Attempted 7 of 3000: Found 2 finishers (28.57%), 5 DNFs, and 0 errors.
# Attempted 8 of 3000: Found 3 finishers (37.50%), 5 DNFs, and 0 errors.
# Attempted 9 of 3000: Found 3 finishers (33.33%), 6 DNFs, and 0 errors.
# Attempted 10 of 3000: Found 3 finishers (30.00%), 7 DNFs, and 0 errors.
# Attempted 11 of 3000: Found 3 finishers (27.27%), 8 DNFs, and 0 errors.
# Attempted 12 of 3000: Found 3 finishers (25.00%), 9 DNFs, and 0 errors.
# Attempted 13 of 3000: Found 4 finishers (30.77%), 9 DNFs, and 0 errors.
# Attempted 14 of 3000: Found 4 finishers (28.57%), 10 DNFs, and 0 errors.
# Attempted 15 of 3000: Found 4 finishers (26.67%), 11 DNFs, and 0 errors.
# Attempted 16 of 3000: Found 4 finishers (25.00%), 12 DNFs, and 0 errors.
# Attempted 17 of 3000: Found 4 finishers (23.53%), 13 DNFs, and 0 errors.
# Attempted 18 of 3000: Found 4 finishers (22.22%), 14 DNFs, and 0 errors.
# Attempted 19 of 3000: Found 4 finishers (21.05%), 15 DNFs, and 0 errors.
# Attempted 20 of 3000: Found 4 finishers (20.00%), 16 DNFs, and 0 errors.
# Attempted 21 of 3000: Found 5 finishers (23.81%), 16 DNFs, and 0 errors.
# Attempted 22 of 3000: Found 5 finishers (22.73%), 17 DNFs, and 0 errors.
# Attempted 23 of 3000: Found 5 finishers (21.74%), 18 DNFs, and 0 errors.
# Attempted 24 of 3000: Found 6 finishers (25.00%), 18 DNFs, and 0 errors.
# Attempted 25 of 3000: Found 6 finishers (24.00%), 19 DNFs, and 0 errors.
# Attempted 26 of 3000: Found 6 finishers (23.08%), 20 DNFs, and 0 errors.
# Attempted 27 of 3000: Found 7 finishers (25.93%), 20 DNFs, and 0 errors.
# Attempted 28 of 3000: Found 7 finishers (25.00%), 21 DNFs, and 0 errors.
# Attempted 29 of 3000: Found 7 finishers (24.14%), 22 DNFs, and 0 errors.
# Attempted 30 of 3000: Found 8 finishers (26.67%), 22 DNFs, and 0 errors.
# Attempted 31 of 3000: Found 8 finishers (25.81%), 23 DNFs, and 0 errors.
# Attempted 32 of 3000: Found 8 finishers (25.00%), 24 DNFs, and 0 errors.
# Attempted 33 of 3000: Found 8 finishers (24.24%), 25 DNFs, and 0 errors.
# Attempted 34 of 3000: Found 8 finishers (23.53%), 26 DNFs, and 0 errors.
# Attempted 35 of 3000: Found 8 finishers (22.86%), 27 DNFs, and 0 errors.
# Attempted 36 of 3000: Found 8 finishers (22.22%), 28 DNFs, and 0 errors.
# Attempted 37 of 3000: Found 8 finishers (21.62%), 29 DNFs, and 0 errors.
# Attempted 38 of 3000: Found 8 finishers (21.05%), 30 DNFs, and 0 errors.
# Attempted 39 of 3000: Found 8 finishers (20.51%), 31 DNFs, and 0 errors.
# Attempted 40 of 3000: Found 9 finishers (22.50%), 31 DNFs, and 0 errors.
# Attempted 41 of 3000: Found 9 finishers (21.95%), 32 DNFs, and 0 errors.
# Attempted 42 of 3000: Found 9 finishers (21.43%), 33 DNFs, and 0 errors.
# Attempted 43 of 3000: Found 9 finishers (20.93%), 34 DNFs, and 0 errors.
# Attempted 44 of 3000: Found 9 finishers (20.45%), 35 DNFs, and 0 errors.
# Attempted 45 of 3000: Found 9 finishers (20.00%), 36 DNFs, and 0 errors.
# Attempted 46 of 3000: Found 9 finishers (19.57%), 37 DNFs, and 0 errors.
# Attempted 47 of 3000: Found 9 finishers (19.15%), 38 DNFs, and 0 errors.
# Attempted 48 of 3000: Found 9 finishers (18.75%), 39 DNFs, and 0 errors.
# Attempted 49 of 3000: Found 9 finishers (18.37%), 40 DNFs, and 0 errors.
# Attempted 50 of 3000: Found 10 finishers (20.00%), 40 DNFs, and 0 errors.
# Attempted 51 of 3000: Found 10 finishers (19.61%), 41 DNFs, and 0 errors.
# Attempted 52 of 3000: Found 10 finishers (19.23%), 42 DNFs, and 0 errors.
# Attempted 53 of 3000: Found 10 finishers (18.87%), 43 DNFs, and 0 errors.
# Attempted 54 of 3000: Found 10 finishers (18.52%), 44 DNFs, and 0 errors.
# Attempted 55 of 3000: Found 10 finishers (18.18%), 45 DNFs, and 0 errors.
# Attempted 56 of 3000: Found 10 finishers (17.86%), 46 DNFs, and 0 errors.
# Attempted 57 of 3000: Found 10 finishers (17.54%), 47 DNFs, and 0 errors.
# Attempted 58 of 3000: Found 10 finishers (17.24%), 48 DNFs, and 0 errors.
# Attempted 59 of 3000: Found 11 finishers (18.64%), 48 DNFs, and 0 errors.
# Attempted 60 of 3000: Found 11 finishers (18.33%), 49 DNFs, and 0 errors.
# Attempted 61 of 3000: Found 11 finishers (18.03%), 50 DNFs, and 0 errors.
# Attempted 62 of 3000: Found 11 finishers (17.74%), 51 DNFs, and 0 errors.
# Attempted 63 of 3000: Found 11 finishers (17.46%), 52 DNFs, and 0 errors.
# Attempted 64 of 3000: Found 11 finishers (17.19%), 53 DNFs, and 0 errors.
# Attempted 65 of 3000: Found 11 finishers (16.92%), 54 DNFs, and 0 errors.
# Attempted 66 of 3000: Found 11 finishers (16.67%), 55 DNFs, and 0 errors.
# Attempted 67 of 3000: Found 11 finishers (16.42%), 56 DNFs, and 0 errors.
# Attempted 68 of 3000: Found 11 finishers (16.18%), 57 DNFs, and 0 errors.
# Attempted 69 of 3000: Found 11 finishers (15.94%), 58 DNFs, and 0 errors.
# Attempted 70 of 3000: Found 11 finishers (15.71%), 59 DNFs, and 0 errors.
# Attempted 71 of 3000: Found 11 finishers (15.49%), 60 DNFs, and 0 errors.
# Attempted 72 of 3000: Found 11 finishers (15.28%), 61 DNFs, and 0 errors.
# Attempted 73 of 3000: Found 11 finishers (15.07%), 62 DNFs, and 0 errors.
# Attempted 74 of 3000: Found 11 finishers (14.86%), 63 DNFs, and 0 errors.
# Attempted 75 of 3000: Found 12 finishers (16.00%), 63 DNFs, and 0 errors.
# Attempted 76 of 3000: Found 12 finishers (15.79%), 64 DNFs, and 0 errors.
# Attempted 77 of 3000: Found 12 finishers (15.58%), 65 DNFs, and 0 errors.
# Attempted 78 of 3000: Found 13 finishers (16.67%), 65 DNFs, and 0 errors.
# Attempted 79 of 3000: Found 13 finishers (16.46%), 66 DNFs, and 0 errors.
# Attempted 80 of 3000: Found 13 finishers (16.25%), 67 DNFs, and 0 errors.
# Attempted 81 of 3000: Found 14 finishers (17.28%), 67 DNFs, and 0 errors.
# Attempted 82 of 3000: Found 14 finishers (17.07%), 68 DNFs, and 0 errors.
# Attempted 83 of 3000: Found 14 finishers (16.87%), 69 DNFs, and 0 errors.
# Attempted 84 of 3000: Found 14 finishers (16.67%), 70 DNFs, and 0 errors.
# Attempted 85 of 3000: Found 14 finishers (16.47%), 71 DNFs, and 0 errors.
# Attempted 86 of 3000: Found 14 finishers (16.28%), 72 DNFs, and 0 errors.
# Attempted 87 of 3000: Found 14 finishers (16.09%), 73 DNFs, and 0 errors.
# Attempted 88 of 3000: Found 14 finishers (15.91%), 74 DNFs, and 0 errors.
# Attempted 89 of 3000: Found 15 finishers (16.85%), 74 DNFs, and 0 errors.
# Attempted 90 of 3000: Found 16 finishers (17.78%), 74 DNFs, and 0 errors.
# Attempted 91 of 3000: Found 16 finishers (17.58%), 75 DNFs, and 0 errors.
# Attempted 92 of 3000: Found 16 finishers (17.39%), 76 DNFs, and 0 errors.
# Attempted 93 of 3000: Found 16 finishers (17.20%), 77 DNFs, and 0 errors.
# Attempted 94 of 3000: Found 16 finishers (17.02%), 78 DNFs, and 0 errors.
# Attempted 95 of 3000: Found 16 finishers (16.84%), 79 DNFs, and 0 errors.
# Attempted 96 of 3000: Found 16 finishers (16.67%), 80 DNFs, and 0 errors.
# Attempted 97 of 3000: Found 16 finishers (16.49%), 81 DNFs, and 0 errors.
# Attempted 98 of 3000: Found 16 finishers (16.33%), 82 DNFs, and 0 errors.
# Attempted 99 of 3000: Found 16 finishers (16.16%), 83 DNFs, and 0 errors.
# Attempted 100 of 3000: Found 16 finishers (16.00%), 84 DNFs, and 0 errors.
# Attempted 101 of 3000: Found 17 finishers (16.83%), 84 DNFs, and 0 errors.
# Attempted 102 of 3000: Found 17 finishers (16.67%), 85 DNFs, and 0 errors.
# Attempted 103 of 3000: Found 17 finishers (16.50%), 86 DNFs, and 0 errors.
# Attempted 104 of 3000: Found 17 finishers (16.35%), 87 DNFs, and 0 errors.
# Attempted 105 of 3000: Found 17 finishers (16.19%), 88 DNFs, and 0 errors.
# Attempted 106 of 3000: Found 17 finishers (16.04%), 89 DNFs, and 0 errors.
# Attempted 107 of 3000: Found 17 finishers (15.89%), 90 DNFs, and 0 errors.
# Attempted 108 of 3000: Found 17 finishers (15.74%), 91 DNFs, and 0 errors.
# Attempted 109 of 3000: Found 17 finishers (15.60%), 92 DNFs, and 0 errors.
# Attempted 110 of 3000: Found 18 finishers (16.36%), 92 DNFs, and 0 errors.
# Attempted 111 of 3000: Found 19 finishers (17.12%), 92 DNFs, and 0 errors.
# Attempted 112 of 3000: Found 19 finishers (16.96%), 93 DNFs, and 0 errors.
# Attempted 113 of 3000: Found 19 finishers (16.81%), 94 DNFs, and 0 errors.
# Attempted 114 of 3000: Found 19 finishers (16.67%), 95 DNFs, and 0 errors.
# Attempted 115 of 3000: Found 19 finishers (16.52%), 96 DNFs, and 0 errors.
# Attempted 116 of 3000: Found 19 finishers (16.38%), 97 DNFs, and 0 errors.
# Attempted 117 of 3000: Found 20 finishers (17.09%), 97 DNFs, and 0 errors.
# Attempted 118 of 3000: Found 20 finishers (16.95%), 98 DNFs, and 0 errors.
# Attempted 119 of 3000: Found 21 finishers (17.65%), 98 DNFs, and 0 errors.
# Attempted 120 of 3000: Found 21 finishers (17.50%), 99 DNFs, and 0 errors.
# Attempted 121 of 3000: Found 21 finishers (17.36%), 100 DNFs, and 0 errors.
# Attempted 122 of 3000: Found 21 finishers (17.21%), 101 DNFs, and 0 errors.
# Attempted 123 of 3000: Found 21 finishers (17.07%), 102 DNFs, and 0 errors.
# Attempted 124 of 3000: Found 22 finishers (17.74%), 102 DNFs, and 0 errors.
# Attempted 125 of 3000: Found 22 finishers (17.60%), 103 DNFs, and 0 errors.
# Attempted 126 of 3000: Found 22 finishers (17.46%), 104 DNFs, and 0 errors.
# Attempted 127 of 3000: Found 22 finishers (17.32%), 105 DNFs, and 0 errors.
# Attempted 128 of 3000: Found 22 finishers (17.19%), 106 DNFs, and 0 errors.
# Attempted 129 of 3000: Found 22 finishers (17.05%), 107 DNFs, and 0 errors.
# Attempted 130 of 3000: Found 22 finishers (16.92%), 108 DNFs, and 0 errors.
# Attempted 131 of 3000: Found 23 finishers (17.56%), 108 DNFs, and 0 errors.
# Attempted 132 of 3000: Found 24 finishers (18.18%), 108 DNFs, and 0 errors.
# Attempted 133 of 3000: Found 24 finishers (18.05%), 109 DNFs, and 0 errors.
# Attempted 134 of 3000: Found 24 finishers (17.91%), 110 DNFs, and 0 errors.
# Attempted 135 of 3000: Found 24 finishers (17.78%), 111 DNFs, and 0 errors.
# Attempted 136 of 3000: Found 24 finishers (17.65%), 112 DNFs, and 0 errors.
# Attempted 137 of 3000: Found 24 finishers (17.52%), 113 DNFs, and 0 errors.
# Attempted 138 of 3000: Found 24 finishers (17.39%), 114 DNFs, and 0 errors.
# Attempted 139 of 3000: Found 24 finishers (17.27%), 115 DNFs, and 0 errors.
# Attempted 140 of 3000: Found 25 finishers (17.86%), 115 DNFs, and 0 errors.
# Attempted 141 of 3000: Found 25 finishers (17.73%), 116 DNFs, and 0 errors.
# Attempted 142 of 3000: Found 26 finishers (18.31%), 116 DNFs, and 0 errors.
# Attempted 143 of 3000: Found 26 finishers (18.18%), 117 DNFs, and 0 errors.
# Attempted 144 of 3000: Found 26 finishers (18.06%), 118 DNFs, and 0 errors.
# Attempted 145 of 3000: Found 26 finishers (17.93%), 119 DNFs, and 0 errors.
# Attempted 146 of 3000: Found 26 finishers (17.81%), 120 DNFs, and 0 errors.
# Attempted 147 of 3000: Found 27 finishers (18.37%), 120 DNFs, and 0 errors.
# Attempted 148 of 3000: Found 28 finishers (18.92%), 120 DNFs, and 0 errors.
# Attempted 149 of 3000: Found 29 finishers (19.46%), 120 DNFs, and 0 errors.
# Attempted 150 of 3000: Found 29 finishers (19.33%), 121 DNFs, and 0 errors.
# Attempted 151 of 3000: Found 30 finishers (19.87%), 121 DNFs, and 0 errors.
# Attempted 152 of 3000: Found 31 finishers (20.39%), 121 DNFs, and 0 errors.
# Attempted 153 of 3000: Found 31 finishers (20.26%), 122 DNFs, and 0 errors.
# Attempted 154 of 3000: Found 31 finishers (20.13%), 123 DNFs, and 0 errors.
# Attempted 155 of 3000: Found 31 finishers (20.00%), 124 DNFs, and 0 errors.
# Attempted 156 of 3000: Found 31 finishers (19.87%), 125 DNFs, and 0 errors.
# Attempted 157 of 3000: Found 31 finishers (19.75%), 126 DNFs, and 0 errors.
# Attempted 158 of 3000: Found 31 finishers (19.62%), 127 DNFs, and 0 errors.
# Attempted 159 of 3000: Found 31 finishers (19.50%), 128 DNFs, and 0 errors.
# Attempted 160 of 3000: Found 31 finishers (19.38%), 129 DNFs, and 0 errors.
# Attempted 161 of 3000: Found 31 finishers (19.25%), 130 DNFs, and 0 errors.
# Attempted 162 of 3000: Found 31 finishers (19.14%), 131 DNFs, and 0 errors.
# Attempted 163 of 3000: Found 31 finishers (19.02%), 132 DNFs, and 0 errors.
# Attempted 164 of 3000: Found 31 finishers (18.90%), 133 DNFs, and 0 errors.
# Attempted 165 of 3000: Found 31 finishers (18.79%), 134 DNFs, and 0 errors.
# Attempted 166 of 3000: Found 31 finishers (18.67%), 135 DNFs, and 0 errors.
# Attempted 167 of 3000: Found 31 finishers (18.56%), 136 DNFs, and 0 errors.
# Attempted 168 of 3000: Found 31 finishers (18.45%), 137 DNFs, and 0 errors.
# Attempted 169 of 3000: Found 31 finishers (18.34%), 138 DNFs, and 0 errors.
# Attempted 170 of 3000: Found 31 finishers (18.24%), 139 DNFs, and 0 errors.
# Attempted 171 of 3000: Found 31 finishers (18.13%), 140 DNFs, and 0 errors.
# Attempted 172 of 3000: Found 31 finishers (18.02%), 141 DNFs, and 0 errors.
# Attempted 173 of 3000: Found 31 finishers (17.92%), 142 DNFs, and 0 errors.
# Attempted 174 of 3000: Found 32 finishers (18.39%), 142 DNFs, and 0 errors.
# Attempted 175 of 3000: Found 32 finishers (18.29%), 143 DNFs, and 0 errors.
# Attempted 176 of 3000: Found 33 finishers (18.75%), 143 DNFs, and 0 errors.
# Attempted 177 of 3000: Found 33 finishers (18.64%), 144 DNFs, and 0 errors.
# Attempted 178 of 3000: Found 33 finishers (18.54%), 145 DNFs, and 0 errors.
# Attempted 179 of 3000: Found 33 finishers (18.44%), 146 DNFs, and 0 errors.
# Attempted 180 of 3000: Found 33 finishers (18.33%), 147 DNFs, and 0 errors.
# Attempted 181 of 3000: Found 33 finishers (18.23%), 148 DNFs, and 0 errors.
# Attempted 182 of 3000: Found 33 finishers (18.13%), 149 DNFs, and 0 errors.
# Attempted 183 of 3000: Found 33 finishers (18.03%), 150 DNFs, and 0 errors.
# Attempted 184 of 3000: Found 33 finishers (17.93%), 151 DNFs, and 0 errors.
# Attempted 185 of 3000: Found 33 finishers (17.84%), 152 DNFs, and 0 errors.
# Attempted 186 of 3000: Found 33 finishers (17.74%), 153 DNFs, and 0 errors.
# Attempted 187 of 3000: Found 34 finishers (18.18%), 153 DNFs, and 0 errors.
# Attempted 188 of 3000: Found 35 finishers (18.62%), 153 DNFs, and 0 errors.
# Attempted 189 of 3000: Found 35 finishers (18.52%), 154 DNFs, and 0 errors.
# Attempted 190 of 3000: Found 35 finishers (18.42%), 155 DNFs, and 0 errors.
# Attempted 191 of 3000: Found 36 finishers (18.85%), 155 DNFs, and 0 errors.
# Attempted 192 of 3000: Found 36 finishers (18.75%), 156 DNFs, and 0 errors.
# Attempted 193 of 3000: Found 37 finishers (19.17%), 156 DNFs, and 0 errors.
# Attempted 194 of 3000: Found 37 finishers (19.07%), 157 DNFs, and 0 errors.
# Attempted 195 of 3000: Found 37 finishers (18.97%), 158 DNFs, and 0 errors.
# Attempted 196 of 3000: Found 38 finishers (19.39%), 158 DNFs, and 0 errors.
# Attempted 197 of 3000: Found 38 finishers (19.29%), 159 DNFs, and 0 errors.
# Attempted 198 of 3000: Found 38 finishers (19.19%), 160 DNFs, and 0 errors.
# Attempted 199 of 3000: Found 39 finishers (19.60%), 160 DNFs, and 0 errors.
# Attempted 200 of 3000: Found 39 finishers (19.50%), 161 DNFs, and 0 errors.
# Attempted 201 of 3000: Found 40 finishers (19.90%), 161 DNFs, and 0 errors.
# Attempted 202 of 3000: Found 40 finishers (19.80%), 162 DNFs, and 0 errors.
# Attempted 203 of 3000: Found 40 finishers (19.70%), 163 DNFs, and 0 errors.
# Attempted 204 of 3000: Found 41 finishers (20.10%), 163 DNFs, and 0 errors.
# Attempted 205 of 3000: Found 41 finishers (20.00%), 164 DNFs, and 0 errors.
# Attempted 206 of 3000: Found 41 finishers (19.90%), 165 DNFs, and 0 errors.
# Attempted 207 of 3000: Found 41 finishers (19.81%), 166 DNFs, and 0 errors.
# Attempted 208 of 3000: Found 41 finishers (19.71%), 167 DNFs, and 0 errors.
# Attempted 209 of 3000: Found 42 finishers (20.10%), 167 DNFs, and 0 errors.
# Attempted 210 of 3000: Found 43 finishers (20.48%), 167 DNFs, and 0 errors.
# Attempted 211 of 3000: Found 43 finishers (20.38%), 168 DNFs, and 0 errors.
# Attempted 212 of 3000: Found 43 finishers (20.28%), 169 DNFs, and 0 errors.
# Attempted 213 of 3000: Found 43 finishers (20.19%), 170 DNFs, and 0 errors.
# Attempted 214 of 3000: Found 43 finishers (20.09%), 171 DNFs, and 0 errors.
# Attempted 215 of 3000: Found 43 finishers (20.00%), 172 DNFs, and 0 errors.
# Attempted 216 of 3000: Found 43 finishers (19.91%), 173 DNFs, and 0 errors.
# Attempted 217 of 3000: Found 43 finishers (19.82%), 174 DNFs, and 0 errors.
# Attempted 218 of 3000: Found 43 finishers (19.72%), 175 DNFs, and 0 errors.
# Attempted 219 of 3000: Found 43 finishers (19.63%), 176 DNFs, and 0 errors.
# Attempted 220 of 3000: Found 43 finishers (19.55%), 177 DNFs, and 0 errors.
# Attempted 221 of 3000: Found 43 finishers (19.46%), 178 DNFs, and 0 errors.
# Attempted 222 of 3000: Found 44 finishers (19.82%), 178 DNFs, and 0 errors.
# Attempted 223 of 3000: Found 44 finishers (19.73%), 179 DNFs, and 0 errors.
# Attempted 224 of 3000: Found 44 finishers (19.64%), 180 DNFs, and 0 errors.
# Attempted 225 of 3000: Found 44 finishers (19.56%), 181 DNFs, and 0 errors.
# Attempted 226 of 3000: Found 44 finishers (19.47%), 182 DNFs, and 0 errors.
# Attempted 227 of 3000: Found 45 finishers (19.82%), 182 DNFs, and 0 errors.
# Attempted 228 of 3000: Found 45 finishers (19.74%), 183 DNFs, and 0 errors.
# Attempted 229 of 3000: Found 45 finishers (19.65%), 184 DNFs, and 0 errors.
# Attempted 230 of 3000: Found 45 finishers (19.57%), 185 DNFs, and 0 errors.
# Attempted 231 of 3000: Found 45 finishers (19.48%), 186 DNFs, and 0 errors.
# Attempted 232 of 3000: Found 45 finishers (19.40%), 187 DNFs, and 0 errors.
# Attempted 233 of 3000: Found 45 finishers (19.31%), 188 DNFs, and 0 errors.
# Attempted 234 of 3000: Found 45 finishers (19.23%), 189 DNFs, and 0 errors.
# Attempted 235 of 3000: Found 45 finishers (19.15%), 190 DNFs, and 0 errors.
# Attempted 236 of 3000: Found 45 finishers (19.07%), 191 DNFs, and 0 errors.
# Attempted 237 of 3000: Found 45 finishers (18.99%), 192 DNFs, and 0 errors.
# Attempted 238 of 3000: Found 45 finishers (18.91%), 193 DNFs, and 0 errors.
# Attempted 239 of 3000: Found 46 finishers (19.25%), 193 DNFs, and 0 errors.
# Attempted 240 of 3000: Found 46 finishers (19.17%), 194 DNFs, and 0 errors.
# Attempted 241 of 3000: Found 46 finishers (19.09%), 195 DNFs, and 0 errors.
# Attempted 242 of 3000: Found 47 finishers (19.42%), 195 DNFs, and 0 errors.
# Attempted 243 of 3000: Found 48 finishers (19.75%), 195 DNFs, and 0 errors.
# Attempted 244 of 3000: Found 49 finishers (20.08%), 195 DNFs, and 0 errors.
# Attempted 245 of 3000: Found 49 finishers (20.00%), 196 DNFs, and 0 errors.
# Attempted 246 of 3000: Found 49 finishers (19.92%), 197 DNFs, and 0 errors.
# Attempted 247 of 3000: Found 49 finishers (19.84%), 198 DNFs, and 0 errors.
# Attempted 248 of 3000: Found 49 finishers (19.76%), 199 DNFs, and 0 errors.
# Attempted 249 of 3000: Found 49 finishers (19.68%), 200 DNFs, and 0 errors.
# Attempted 250 of 3000: Found 49 finishers (19.60%), 201 DNFs, and 0 errors.
# Attempted 251 of 3000: Found 50 finishers (19.92%), 201 DNFs, and 0 errors.
# Attempted 252 of 3000: Found 51 finishers (20.24%), 201 DNFs, and 0 errors.
# Attempted 253 of 3000: Found 51 finishers (20.16%), 202 DNFs, and 0 errors.
# Attempted 254 of 3000: Found 51 finishers (20.08%), 203 DNFs, and 0 errors.
# Attempted 255 of 3000: Found 51 finishers (20.00%), 204 DNFs, and 0 errors.
# Attempted 256 of 3000: Found 51 finishers (19.92%), 205 DNFs, and 0 errors.
# Attempted 257 of 3000: Found 51 finishers (19.84%), 206 DNFs, and 0 errors.
# Attempted 258 of 3000: Found 51 finishers (19.77%), 207 DNFs, and 0 errors.
# Attempted 259 of 3000: Found 51 finishers (19.69%), 208 DNFs, and 0 errors.
# Attempted 260 of 3000: Found 51 finishers (19.62%), 209 DNFs, and 0 errors.
# Attempted 261 of 3000: Found 52 finishers (19.92%), 209 DNFs, and 0 errors.
# Attempted 262 of 3000: Found 52 finishers (19.85%), 210 DNFs, and 0 errors.
# Attempted 263 of 3000: Found 53 finishers (20.15%), 210 DNFs, and 0 errors.
# Attempted 264 of 3000: Found 53 finishers (20.08%), 211 DNFs, and 0 errors.
# Attempted 265 of 3000: Found 53 finishers (20.00%), 212 DNFs, and 0 errors.
# Attempted 266 of 3000: Found 54 finishers (20.30%), 212 DNFs, and 0 errors.
# Attempted 267 of 3000: Found 54 finishers (20.22%), 213 DNFs, and 0 errors.
# Attempted 268 of 3000: Found 55 finishers (20.52%), 213 DNFs, and 0 errors.
# Attempted 269 of 3000: Found 55 finishers (20.45%), 214 DNFs, and 0 errors.
# Attempted 270 of 3000: Found 55 finishers (20.37%), 215 DNFs, and 0 errors.
# Attempted 271 of 3000: Found 55 finishers (20.30%), 216 DNFs, and 0 errors.
# Attempted 272 of 3000: Found 55 finishers (20.22%), 217 DNFs, and 0 errors.
# Attempted 273 of 3000: Found 55 finishers (20.15%), 218 DNFs, and 0 errors.
# Attempted 274 of 3000: Found 56 finishers (20.44%), 218 DNFs, and 0 errors.
# Attempted 275 of 3000: Found 56 finishers (20.36%), 219 DNFs, and 0 errors.
# Attempted 276 of 3000: Found 56 finishers (20.29%), 220 DNFs, and 0 errors.
# Attempted 277 of 3000: Found 56 finishers (20.22%), 221 DNFs, and 0 errors.
# Attempted 278 of 3000: Found 56 finishers (20.14%), 222 DNFs, and 0 errors.
# Attempted 279 of 3000: Found 56 finishers (20.07%), 223 DNFs, and 0 errors.
# Attempted 280 of 3000: Found 56 finishers (20.00%), 224 DNFs, and 0 errors.
# Attempted 281 of 3000: Found 56 finishers (19.93%), 225 DNFs, and 0 errors.
# Attempted 282 of 3000: Found 56 finishers (19.86%), 226 DNFs, and 0 errors.
# Attempted 283 of 3000: Found 56 finishers (19.79%), 227 DNFs, and 0 errors.
# Attempted 284 of 3000: Found 56 finishers (19.72%), 228 DNFs, and 0 errors.
# Attempted 285 of 3000: Found 56 finishers (19.65%), 229 DNFs, and 0 errors.
# Attempted 286 of 3000: Found 56 finishers (19.58%), 230 DNFs, and 0 errors.
# Attempted 287 of 3000: Found 56 finishers (19.51%), 231 DNFs, and 0 errors.
# Attempted 288 of 3000: Found 56 finishers (19.44%), 232 DNFs, and 0 errors.
# Attempted 289 of 3000: Found 57 finishers (19.72%), 232 DNFs, and 0 errors.
# Attempted 290 of 3000: Found 57 finishers (19.66%), 233 DNFs, and 0 errors.
# Attempted 291 of 3000: Found 57 finishers (19.59%), 234 DNFs, and 0 errors.
# Attempted 292 of 3000: Found 57 finishers (19.52%), 235 DNFs, and 0 errors.
# Attempted 293 of 3000: Found 57 finishers (19.45%), 236 DNFs, and 0 errors.
# Attempted 294 of 3000: Found 57 finishers (19.39%), 237 DNFs, and 0 errors.
# Attempted 295 of 3000: Found 57 finishers (19.32%), 238 DNFs, and 0 errors.
# Attempted 296 of 3000: Found 57 finishers (19.26%), 239 DNFs, and 0 errors.
# Attempted 297 of 3000: Found 58 finishers (19.53%), 239 DNFs, and 0 errors.
# Attempted 298 of 3000: Found 58 finishers (19.46%), 240 DNFs, and 0 errors.
# Attempted 299 of 3000: Found 58 finishers (19.40%), 241 DNFs, and 0 errors.
# Attempted 300 of 3000: Found 58 finishers (19.33%), 242 DNFs, and 0 errors.
# Attempted 301 of 3000: Found 58 finishers (19.27%), 243 DNFs, and 0 errors.
# Attempted 302 of 3000: Found 58 finishers (19.21%), 244 DNFs, and 0 errors.
# Attempted 303 of 3000: Found 58 finishers (19.14%), 245 DNFs, and 0 errors.
# Attempted 304 of 3000: Found 58 finishers (19.08%), 246 DNFs, and 0 errors.
# Attempted 305 of 3000: Found 58 finishers (19.02%), 247 DNFs, and 0 errors.
# Attempted 306 of 3000: Found 58 finishers (18.95%), 248 DNFs, and 0 errors.
# Attempted 307 of 3000: Found 58 finishers (18.89%), 249 DNFs, and 0 errors.
# Attempted 308 of 3000: Found 58 finishers (18.83%), 250 DNFs, and 0 errors.
# Attempted 309 of 3000: Found 58 finishers (18.77%), 251 DNFs, and 0 errors.
# Attempted 310 of 3000: Found 59 finishers (19.03%), 251 DNFs, and 0 errors.
# Attempted 311 of 3000: Found 59 finishers (18.97%), 252 DNFs, and 0 errors.
# Attempted 312 of 3000: Found 59 finishers (18.91%), 253 DNFs, and 0 errors.
# Attempted 313 of 3000: Found 59 finishers (18.85%), 254 DNFs, and 0 errors.
# Attempted 314 of 3000: Found 60 finishers (19.11%), 254 DNFs, and 0 errors.
# Attempted 315 of 3000: Found 61 finishers (19.37%), 254 DNFs, and 0 errors.
# Attempted 316 of 3000: Found 61 finishers (19.30%), 255 DNFs, and 0 errors.
# Attempted 317 of 3000: Found 61 finishers (19.24%), 256 DNFs, and 0 errors.
# Attempted 318 of 3000: Found 61 finishers (19.18%), 257 DNFs, and 0 errors.
# Attempted 319 of 3000: Found 61 finishers (19.12%), 258 DNFs, and 0 errors.
# Attempted 320 of 3000: Found 61 finishers (19.06%), 259 DNFs, and 0 errors.
# Attempted 321 of 3000: Found 61 finishers (19.00%), 260 DNFs, and 0 errors.
# Attempted 322 of 3000: Found 61 finishers (18.94%), 261 DNFs, and 0 errors.
# Attempted 323 of 3000: Found 61 finishers (18.89%), 262 DNFs, and 0 errors.
# Attempted 324 of 3000: Found 61 finishers (18.83%), 263 DNFs, and 0 errors.
# Attempted 325 of 3000: Found 61 finishers (18.77%), 264 DNFs, and 0 errors.
# Attempted 326 of 3000: Found 61 finishers (18.71%), 265 DNFs, and 0 errors.
# Attempted 327 of 3000: Found 61 finishers (18.65%), 266 DNFs, and 0 errors.
# Attempted 328 of 3000: Found 61 finishers (18.60%), 267 DNFs, and 0 errors.
# Attempted 329 of 3000: Found 61 finishers (18.54%), 268 DNFs, and 0 errors.
# Attempted 330 of 3000: Found 61 finishers (18.48%), 269 DNFs, and 0 errors.
# Attempted 331 of 3000: Found 61 finishers (18.43%), 270 DNFs, and 0 errors.
# Attempted 332 of 3000: Found 61 finishers (18.37%), 271 DNFs, and 0 errors.
# Attempted 333 of 3000: Found 61 finishers (18.32%), 272 DNFs, and 0 errors.
# Attempted 334 of 3000: Found 61 finishers (18.26%), 273 DNFs, and 0 errors.
# Attempted 335 of 3000: Found 61 finishers (18.21%), 274 DNFs, and 0 errors.
# Attempted 336 of 3000: Found 62 finishers (18.45%), 274 DNFs, and 0 errors.
# Attempted 337 of 3000: Found 62 finishers (18.40%), 275 DNFs, and 0 errors.
# Attempted 338 of 3000: Found 62 finishers (18.34%), 276 DNFs, and 0 errors.
# Attempted 339 of 3000: Found 62 finishers (18.29%), 277 DNFs, and 0 errors.
# Attempted 340 of 3000: Found 62 finishers (18.24%), 278 DNFs, and 0 errors.
# Attempted 341 of 3000: Found 62 finishers (18.18%), 279 DNFs, and 0 errors.
# Attempted 342 of 3000: Found 62 finishers (18.13%), 280 DNFs, and 0 errors.
# Attempted 343 of 3000: Found 63 finishers (18.37%), 280 DNFs, and 0 errors.
# Attempted 344 of 3000: Found 63 finishers (18.31%), 281 DNFs, and 0 errors.
# Attempted 345 of 3000: Found 63 finishers (18.26%), 282 DNFs, and 0 errors.
# Attempted 346 of 3000: Found 63 finishers (18.21%), 283 DNFs, and 0 errors.
# Attempted 347 of 3000: Found 64 finishers (18.44%), 283 DNFs, and 0 errors.
# Attempted 348 of 3000: Found 64 finishers (18.39%), 284 DNFs, and 0 errors.
# Attempted 349 of 3000: Found 65 finishers (18.62%), 284 DNFs, and 0 errors.
# Attempted 350 of 3000: Found 65 finishers (18.57%), 285 DNFs, and 0 errors.
# Attempted 351 of 3000: Found 65 finishers (18.52%), 286 DNFs, and 0 errors.
# Attempted 352 of 3000: Found 65 finishers (18.47%), 287 DNFs, and 0 errors.
# Attempted 353 of 3000: Found 66 finishers (18.70%), 287 DNFs, and 0 errors.
# Attempted 354 of 3000: Found 66 finishers (18.64%), 288 DNFs, and 0 errors.
# Attempted 355 of 3000: Found 66 finishers (18.59%), 289 DNFs, and 0 errors.
# Attempted 356 of 3000: Found 67 finishers (18.82%), 289 DNFs, and 0 errors.
# Attempted 357 of 3000: Found 67 finishers (18.77%), 290 DNFs, and 0 errors.
# Attempted 358 of 3000: Found 68 finishers (18.99%), 290 DNFs, and 0 errors.
# Attempted 359 of 3000: Found 68 finishers (18.94%), 291 DNFs, and 0 errors.
# Attempted 360 of 3000: Found 68 finishers (18.89%), 292 DNFs, and 0 errors.
# Attempted 361 of 3000: Found 68 finishers (18.84%), 293 DNFs, and 0 errors.
# Attempted 362 of 3000: Found 68 finishers (18.78%), 294 DNFs, and 0 errors.
# Attempted 363 of 3000: Found 68 finishers (18.73%), 295 DNFs, and 0 errors.
# Attempted 364 of 3000: Found 68 finishers (18.68%), 296 DNFs, and 0 errors.
# Attempted 365 of 3000: Found 69 finishers (18.90%), 296 DNFs, and 0 errors.
# Attempted 366 of 3000: Found 69 finishers (18.85%), 297 DNFs, and 0 errors.
# Attempted 367 of 3000: Found 69 finishers (18.80%), 298 DNFs, and 0 errors.
# Attempted 368 of 3000: Found 69 finishers (18.75%), 299 DNFs, and 0 errors.
# Attempted 369 of 3000: Found 69 finishers (18.70%), 300 DNFs, and 0 errors.
# Attempted 370 of 3000: Found 69 finishers (18.65%), 301 DNFs, and 0 errors.
# Attempted 371 of 3000: Found 69 finishers (18.60%), 302 DNFs, and 0 errors.
# Attempted 372 of 3000: Found 69 finishers (18.55%), 303 DNFs, and 0 errors.
# Attempted 373 of 3000: Found 69 finishers (18.50%), 304 DNFs, and 0 errors.
# Attempted 374 of 3000: Found 69 finishers (18.45%), 305 DNFs, and 0 errors.
# Attempted 375 of 3000: Found 69 finishers (18.40%), 306 DNFs, and 0 errors.
# Attempted 376 of 3000: Found 70 finishers (18.62%), 306 DNFs, and 0 errors.
# Attempted 377 of 3000: Found 71 finishers (18.83%), 306 DNFs, and 0 errors.
# Attempted 378 of 3000: Found 71 finishers (18.78%), 307 DNFs, and 0 errors.
# Attempted 379 of 3000: Found 72 finishers (19.00%), 307 DNFs, and 0 errors.
# Attempted 380 of 3000: Found 72 finishers (18.95%), 308 DNFs, and 0 errors.
# Attempted 381 of 3000: Found 72 finishers (18.90%), 309 DNFs, and 0 errors.
# Attempted 382 of 3000: Found 72 finishers (18.85%), 310 DNFs, and 0 errors.
# Attempted 383 of 3000: Found 72 finishers (18.80%), 311 DNFs, and 0 errors.
# Attempted 384 of 3000: Found 72 finishers (18.75%), 312 DNFs, and 0 errors.
# Attempted 385 of 3000: Found 72 finishers (18.70%), 313 DNFs, and 0 errors.
# Attempted 386 of 3000: Found 72 finishers (18.65%), 314 DNFs, and 0 errors.
# Attempted 387 of 3000: Found 72 finishers (18.60%), 315 DNFs, and 0 errors.
# Attempted 388 of 3000: Found 73 finishers (18.81%), 315 DNFs, and 0 errors.
# Attempted 389 of 3000: Found 74 finishers (19.02%), 315 DNFs, and 0 errors.
# Attempted 390 of 3000: Found 74 finishers (18.97%), 316 DNFs, and 0 errors.
# Attempted 391 of 3000: Found 74 finishers (18.93%), 317 DNFs, and 0 errors.
# Attempted 392 of 3000: Found 74 finishers (18.88%), 318 DNFs, and 0 errors.
# Attempted 393 of 3000: Found 74 finishers (18.83%), 319 DNFs, and 0 errors.
# Attempted 394 of 3000: Found 74 finishers (18.78%), 320 DNFs, and 0 errors.
# Attempted 395 of 3000: Found 74 finishers (18.73%), 321 DNFs, and 0 errors.
# Attempted 396 of 3000: Found 74 finishers (18.69%), 322 DNFs, and 0 errors.
# Attempted 397 of 3000: Found 74 finishers (18.64%), 323 DNFs, and 0 errors.
# Attempted 398 of 3000: Found 74 finishers (18.59%), 324 DNFs, and 0 errors.
# Attempted 399 of 3000: Found 74 finishers (18.55%), 325 DNFs, and 0 errors.
# Attempted 400 of 3000: Found 74 finishers (18.50%), 326 DNFs, and 0 errors.
# Attempted 401 of 3000: Found 74 finishers (18.45%), 327 DNFs, and 0 errors.
# Attempted 402 of 3000: Found 74 finishers (18.41%), 328 DNFs, and 0 errors.
# Attempted 403 of 3000: Found 74 finishers (18.36%), 329 DNFs, and 0 errors.
# Attempted 404 of 3000: Found 74 finishers (18.32%), 330 DNFs, and 0 errors.
# Attempted 405 of 3000: Found 75 finishers (18.52%), 330 DNFs, and 0 errors.
# Attempted 406 of 3000: Found 75 finishers (18.47%), 331 DNFs, and 0 errors.
# Attempted 407 of 3000: Found 76 finishers (18.67%), 331 DNFs, and 0 errors.
# Attempted 408 of 3000: Found 76 finishers (18.63%), 332 DNFs, and 0 errors.
# Attempted 409 of 3000: Found 76 finishers (18.58%), 333 DNFs, and 0 errors.
# Attempted 410 of 3000: Found 77 finishers (18.78%), 333 DNFs, and 0 errors.
# Attempted 411 of 3000: Found 77 finishers (18.73%), 334 DNFs, and 0 errors.
# Attempted 412 of 3000: Found 77 finishers (18.69%), 335 DNFs, and 0 errors.
# Attempted 413 of 3000: Found 77 finishers (18.64%), 336 DNFs, and 0 errors.
# Attempted 414 of 3000: Found 77 finishers (18.60%), 337 DNFs, and 0 errors.
# Attempted 415 of 3000: Found 77 finishers (18.55%), 338 DNFs, and 0 errors.
# Attempted 416 of 3000: Found 77 finishers (18.51%), 339 DNFs, and 0 errors.
# Attempted 417 of 3000: Found 77 finishers (18.47%), 340 DNFs, and 0 errors.
# Attempted 418 of 3000: Found 77 finishers (18.42%), 341 DNFs, and 0 errors.
# Attempted 419 of 3000: Found 77 finishers (18.38%), 342 DNFs, and 0 errors.
# Attempted 420 of 3000: Found 77 finishers (18.33%), 343 DNFs, and 0 errors.
# Attempted 421 of 3000: Found 77 finishers (18.29%), 344 DNFs, and 0 errors.
# Attempted 422 of 3000: Found 77 finishers (18.25%), 345 DNFs, and 0 errors.
# Attempted 423 of 3000: Found 77 finishers (18.20%), 346 DNFs, and 0 errors.
# Attempted 424 of 3000: Found 77 finishers (18.16%), 347 DNFs, and 0 errors.
# Attempted 425 of 3000: Found 77 finishers (18.12%), 348 DNFs, and 0 errors.
# Attempted 426 of 3000: Found 77 finishers (18.08%), 349 DNFs, and 0 errors.
# Attempted 427 of 3000: Found 78 finishers (18.27%), 349 DNFs, and 0 errors.
# Attempted 428 of 3000: Found 78 finishers (18.22%), 350 DNFs, and 0 errors.
# Attempted 429 of 3000: Found 78 finishers (18.18%), 351 DNFs, and 0 errors.
# Attempted 430 of 3000: Found 78 finishers (18.14%), 352 DNFs, and 0 errors.
# Attempted 431 of 3000: Found 79 finishers (18.33%), 352 DNFs, and 0 errors.
# Attempted 432 of 3000: Found 79 finishers (18.29%), 353 DNFs, and 0 errors.
# Attempted 433 of 3000: Found 79 finishers (18.24%), 354 DNFs, and 0 errors.
# Attempted 434 of 3000: Found 79 finishers (18.20%), 355 DNFs, and 0 errors.
# Attempted 435 of 3000: Found 79 finishers (18.16%), 356 DNFs, and 0 errors.
# Attempted 436 of 3000: Found 80 finishers (18.35%), 356 DNFs, and 0 errors.
# Attempted 437 of 3000: Found 80 finishers (18.31%), 357 DNFs, and 0 errors.
# Attempted 438 of 3000: Found 81 finishers (18.49%), 357 DNFs, and 0 errors.
# Attempted 439 of 3000: Found 81 finishers (18.45%), 358 DNFs, and 0 errors.
# Attempted 440 of 3000: Found 81 finishers (18.41%), 359 DNFs, and 0 errors.
# Attempted 441 of 3000: Found 81 finishers (18.37%), 360 DNFs, and 0 errors.
# Attempted 442 of 3000: Found 81 finishers (18.33%), 361 DNFs, and 0 errors.
# Attempted 443 of 3000: Found 81 finishers (18.28%), 362 DNFs, and 0 errors.
# Attempted 444 of 3000: Found 81 finishers (18.24%), 363 DNFs, and 0 errors.
# Attempted 445 of 3000: Found 81 finishers (18.20%), 364 DNFs, and 0 errors.
# Attempted 446 of 3000: Found 81 finishers (18.16%), 365 DNFs, and 0 errors.
# Attempted 447 of 3000: Found 82 finishers (18.34%), 365 DNFs, and 0 errors.
# Attempted 448 of 3000: Found 82 finishers (18.30%), 366 DNFs, and 0 errors.
# Attempted 449 of 3000: Found 82 finishers (18.26%), 367 DNFs, and 0 errors.
# Attempted 450 of 3000: Found 82 finishers (18.22%), 368 DNFs, and 0 errors.
# Attempted 451 of 3000: Found 82 finishers (18.18%), 369 DNFs, and 0 errors.
# Attempted 452 of 3000: Found 83 finishers (18.36%), 369 DNFs, and 0 errors.
# Attempted 453 of 3000: Found 83 finishers (18.32%), 370 DNFs, and 0 errors.
# Attempted 454 of 3000: Found 83 finishers (18.28%), 371 DNFs, and 0 errors.
# Attempted 455 of 3000: Found 83 finishers (18.24%), 372 DNFs, and 0 errors.
# Attempted 456 of 3000: Found 83 finishers (18.20%), 373 DNFs, and 0 errors.
# Attempted 457 of 3000: Found 84 finishers (18.38%), 373 DNFs, and 0 errors.
# Attempted 458 of 3000: Found 84 finishers (18.34%), 374 DNFs, and 0 errors.
# Attempted 459 of 3000: Found 84 finishers (18.30%), 375 DNFs, and 0 errors.
# Attempted 460 of 3000: Found 84 finishers (18.26%), 376 DNFs, and 0 errors.
# Attempted 461 of 3000: Found 84 finishers (18.22%), 377 DNFs, and 0 errors.
# Attempted 462 of 3000: Found 84 finishers (18.18%), 378 DNFs, and 0 errors.
# Attempted 463 of 3000: Found 84 finishers (18.14%), 379 DNFs, and 0 errors.
# Attempted 464 of 3000: Found 84 finishers (18.10%), 380 DNFs, and 0 errors.
# Attempted 465 of 3000: Found 84 finishers (18.06%), 381 DNFs, and 0 errors.
# Attempted 466 of 3000: Found 84 finishers (18.03%), 382 DNFs, and 0 errors.
# Attempted 467 of 3000: Found 85 finishers (18.20%), 382 DNFs, and 0 errors.
# Attempted 468 of 3000: Found 85 finishers (18.16%), 383 DNFs, and 0 errors.
# Attempted 469 of 3000: Found 86 finishers (18.34%), 383 DNFs, and 0 errors.
# Attempted 470 of 3000: Found 86 finishers (18.30%), 384 DNFs, and 0 errors.
# Attempted 471 of 3000: Found 86 finishers (18.26%), 385 DNFs, and 0 errors.
# Attempted 472 of 3000: Found 86 finishers (18.22%), 386 DNFs, and 0 errors.
# Attempted 473 of 3000: Found 86 finishers (18.18%), 387 DNFs, and 0 errors.
# Attempted 474 of 3000: Found 86 finishers (18.14%), 388 DNFs, and 0 errors.
# Attempted 475 of 3000: Found 87 finishers (18.32%), 388 DNFs, and 0 errors.
# Attempted 476 of 3000: Found 87 finishers (18.28%), 389 DNFs, and 0 errors.
# Attempted 477 of 3000: Found 87 finishers (18.24%), 390 DNFs, and 0 errors.
# Attempted 478 of 3000: Found 87 finishers (18.20%), 391 DNFs, and 0 errors.
# Attempted 479 of 3000: Found 88 finishers (18.37%), 391 DNFs, and 0 errors.
# Attempted 480 of 3000: Found 88 finishers (18.33%), 392 DNFs, and 0 errors.
# Attempted 481 of 3000: Found 88 finishers (18.30%), 393 DNFs, and 0 errors.
# Attempted 482 of 3000: Found 88 finishers (18.26%), 394 DNFs, and 0 errors.
# Attempted 483 of 3000: Found 88 finishers (18.22%), 395 DNFs, and 0 errors.
# Attempted 484 of 3000: Found 88 finishers (18.18%), 396 DNFs, and 0 errors.
# Attempted 485 of 3000: Found 89 finishers (18.35%), 396 DNFs, and 0 errors.
# Attempted 486 of 3000: Found 89 finishers (18.31%), 397 DNFs, and 0 errors.
# Attempted 487 of 3000: Found 89 finishers (18.28%), 398 DNFs, and 0 errors.
# Attempted 488 of 3000: Found 89 finishers (18.24%), 399 DNFs, and 0 errors.
# Attempted 489 of 3000: Found 89 finishers (18.20%), 400 DNFs, and 0 errors.
# Attempted 490 of 3000: Found 90 finishers (18.37%), 400 DNFs, and 0 errors.
# Attempted 491 of 3000: Found 91 finishers (18.53%), 400 DNFs, and 0 errors.
# Attempted 492 of 3000: Found 91 finishers (18.50%), 401 DNFs, and 0 errors.
# Attempted 493 of 3000: Found 91 finishers (18.46%), 402 DNFs, and 0 errors.
# Attempted 494 of 3000: Found 92 finishers (18.62%), 402 DNFs, and 0 errors.
# Attempted 495 of 3000: Found 92 finishers (18.59%), 403 DNFs, and 0 errors.
# Attempted 496 of 3000: Found 92 finishers (18.55%), 404 DNFs, and 0 errors.
# Attempted 497 of 3000: Found 92 finishers (18.51%), 405 DNFs, and 0 errors.
# Attempted 498 of 3000: Found 92 finishers (18.47%), 406 DNFs, and 0 errors.
# Attempted 499 of 3000: Found 92 finishers (18.44%), 407 DNFs, and 0 errors.
# Attempted 500 of 3000: Found 93 finishers (18.60%), 407 DNFs, and 0 errors.
# Attempted 501 of 3000: Found 94 finishers (18.76%), 407 DNFs, and 0 errors.
# Attempted 502 of 3000: Found 94 finishers (18.73%), 408 DNFs, and 0 errors.
# Attempted 503 of 3000: Found 94 finishers (18.69%), 409 DNFs, and 0 errors.
# Attempted 504 of 3000: Found 94 finishers (18.65%), 410 DNFs, and 0 errors.
# Attempted 505 of 3000: Found 95 finishers (18.81%), 410 DNFs, and 0 errors.
# Attempted 506 of 3000: Found 95 finishers (18.77%), 411 DNFs, and 0 errors.
# Attempted 507 of 3000: Found 95 finishers (18.74%), 412 DNFs, and 0 errors.
# Attempted 508 of 3000: Found 96 finishers (18.90%), 412 DNFs, and 0 errors.
# Attempted 509 of 3000: Found 96 finishers (18.86%), 413 DNFs, and 0 errors.
# Attempted 510 of 3000: Found 96 finishers (18.82%), 414 DNFs, and 0 errors.
# Attempted 511 of 3000: Found 96 finishers (18.79%), 415 DNFs, and 0 errors.
# Attempted 512 of 3000: Found 96 finishers (18.75%), 416 DNFs, and 0 errors.
# Attempted 513 of 3000: Found 96 finishers (18.71%), 417 DNFs, and 0 errors.
# Attempted 514 of 3000: Found 96 finishers (18.68%), 418 DNFs, and 0 errors.
# Attempted 515 of 3000: Found 96 finishers (18.64%), 419 DNFs, and 0 errors.
# Attempted 516 of 3000: Found 96 finishers (18.60%), 420 DNFs, and 0 errors.
# Attempted 517 of 3000: Found 97 finishers (18.76%), 420 DNFs, and 0 errors.
# Attempted 518 of 3000: Found 98 finishers (18.92%), 420 DNFs, and 0 errors.
# Attempted 519 of 3000: Found 98 finishers (18.88%), 421 DNFs, and 0 errors.
# Attempted 520 of 3000: Found 98 finishers (18.85%), 422 DNFs, and 0 errors.
# Attempted 521 of 3000: Found 98 finishers (18.81%), 423 DNFs, and 0 errors.
# Attempted 522 of 3000: Found 98 finishers (18.77%), 424 DNFs, and 0 errors.
# Attempted 523 of 3000: Found 98 finishers (18.74%), 425 DNFs, and 0 errors.
# Attempted 524 of 3000: Found 98 finishers (18.70%), 426 DNFs, and 0 errors.
# Attempted 525 of 3000: Found 98 finishers (18.67%), 427 DNFs, and 0 errors.
# Attempted 526 of 3000: Found 99 finishers (18.82%), 427 DNFs, and 0 errors.
# Attempted 527 of 3000: Found 99 finishers (18.79%), 428 DNFs, and 0 errors.
# Attempted 528 of 3000: Found 99 finishers (18.75%), 429 DNFs, and 0 errors.
# Attempted 529 of 3000: Found 99 finishers (18.71%), 430 DNFs, and 0 errors.
# Attempted 530 of 3000: Found 99 finishers (18.68%), 431 DNFs, and 0 errors.
# Attempted 531 of 3000: Found 99 finishers (18.64%), 432 DNFs, and 0 errors.
# Attempted 532 of 3000: Found 100 finishers (18.80%), 432 DNFs, and 0 errors.
# Attempted 533 of 3000: Found 101 finishers (18.95%), 432 DNFs, and 0 errors.
# Attempted 534 of 3000: Found 101 finishers (18.91%), 433 DNFs, and 0 errors.
# Attempted 535 of 3000: Found 101 finishers (18.88%), 434 DNFs, and 0 errors.
# Attempted 536 of 3000: Found 101 finishers (18.84%), 435 DNFs, and 0 errors.
# Attempted 537 of 3000: Found 102 finishers (18.99%), 435 DNFs, and 0 errors.
# Attempted 538 of 3000: Found 102 finishers (18.96%), 436 DNFs, and 0 errors.
# Attempted 539 of 3000: Found 102 finishers (18.92%), 437 DNFs, and 0 errors.
# Attempted 540 of 3000: Found 102 finishers (18.89%), 438 DNFs, and 0 errors.
# Attempted 541 of 3000: Found 102 finishers (18.85%), 439 DNFs, and 0 errors.
# Attempted 542 of 3000: Found 102 finishers (18.82%), 440 DNFs, and 0 errors.
# Attempted 543 of 3000: Found 102 finishers (18.78%), 441 DNFs, and 0 errors.
# Attempted 544 of 3000: Found 102 finishers (18.75%), 442 DNFs, and 0 errors.
# Attempted 545 of 3000: Found 102 finishers (18.72%), 443 DNFs, and 0 errors.
# Attempted 546 of 3000: Found 103 finishers (18.86%), 443 DNFs, and 0 errors.
# Attempted 547 of 3000: Found 103 finishers (18.83%), 444 DNFs, and 0 errors.
# Attempted 548 of 3000: Found 103 finishers (18.80%), 445 DNFs, and 0 errors.
# Attempted 549 of 3000: Found 104 finishers (18.94%), 445 DNFs, and 0 errors.
# Attempted 550 of 3000: Found 104 finishers (18.91%), 446 DNFs, and 0 errors.
# Attempted 551 of 3000: Found 104 finishers (18.87%), 447 DNFs, and 0 errors.
# Attempted 552 of 3000: Found 104 finishers (18.84%), 448 DNFs, and 0 errors.
# Attempted 553 of 3000: Found 104 finishers (18.81%), 449 DNFs, and 0 errors.
# Attempted 554 of 3000: Found 104 finishers (18.77%), 450 DNFs, and 0 errors.
# Attempted 555 of 3000: Found 104 finishers (18.74%), 451 DNFs, and 0 errors.
# Attempted 556 of 3000: Found 104 finishers (18.71%), 452 DNFs, and 0 errors.
# Attempted 557 of 3000: Found 104 finishers (18.67%), 453 DNFs, and 0 errors.
# Attempted 558 of 3000: Found 104 finishers (18.64%), 454 DNFs, and 0 errors.
# Attempted 559 of 3000: Found 104 finishers (18.60%), 455 DNFs, and 0 errors.
# Attempted 560 of 3000: Found 104 finishers (18.57%), 456 DNFs, and 0 errors.
# Attempted 561 of 3000: Found 104 finishers (18.54%), 457 DNFs, and 0 errors.
# Attempted 562 of 3000: Found 105 finishers (18.68%), 457 DNFs, and 0 errors.
# Attempted 563 of 3000: Found 105 finishers (18.65%), 458 DNFs, and 0 errors.
# Attempted 564 of 3000: Found 105 finishers (18.62%), 459 DNFs, and 0 errors.
# Attempted 565 of 3000: Found 105 finishers (18.58%), 460 DNFs, and 0 errors.
# Attempted 566 of 3000: Found 105 finishers (18.55%), 461 DNFs, and 0 errors.
# Attempted 567 of 3000: Found 106 finishers (18.69%), 461 DNFs, and 0 errors.
# Attempted 568 of 3000: Found 106 finishers (18.66%), 462 DNFs, and 0 errors.
# Attempted 569 of 3000: Found 106 finishers (18.63%), 463 DNFs, and 0 errors.
# Attempted 570 of 3000: Found 106 finishers (18.60%), 464 DNFs, and 0 errors.
# Attempted 571 of 3000: Found 106 finishers (18.56%), 465 DNFs, and 0 errors.
# Attempted 572 of 3000: Found 107 finishers (18.71%), 465 DNFs, and 0 errors.
# Attempted 573 of 3000: Found 107 finishers (18.67%), 466 DNFs, and 0 errors.
# Attempted 574 of 3000: Found 107 finishers (18.64%), 467 DNFs, and 0 errors.
# Attempted 575 of 3000: Found 107 finishers (18.61%), 468 DNFs, and 0 errors.
# Attempted 576 of 3000: Found 107 finishers (18.58%), 469 DNFs, and 0 errors.
# Attempted 577 of 3000: Found 107 finishers (18.54%), 470 DNFs, and 0 errors.
# Attempted 578 of 3000: Found 107 finishers (18.51%), 471 DNFs, and 0 errors.
# Attempted 579 of 3000: Found 107 finishers (18.48%), 472 DNFs, and 0 errors.
# Attempted 580 of 3000: Found 107 finishers (18.45%), 473 DNFs, and 0 errors.
# Attempted 581 of 3000: Found 107 finishers (18.42%), 474 DNFs, and 0 errors.
# Attempted 582 of 3000: Found 107 finishers (18.38%), 475 DNFs, and 0 errors.
# Attempted 583 of 3000: Found 108 finishers (18.52%), 475 DNFs, and 0 errors.
# Attempted 584 of 3000: Found 108 finishers (18.49%), 476 DNFs, and 0 errors.
# Attempted 585 of 3000: Found 109 finishers (18.63%), 476 DNFs, and 0 errors.
# Attempted 586 of 3000: Found 109 finishers (18.60%), 477 DNFs, and 0 errors.
# Attempted 587 of 3000: Found 110 finishers (18.74%), 477 DNFs, and 0 errors.
# Attempted 588 of 3000: Found 110 finishers (18.71%), 478 DNFs, and 0 errors.
# Attempted 589 of 3000: Found 111 finishers (18.85%), 478 DNFs, and 0 errors.
# Attempted 590 of 3000: Found 111 finishers (18.81%), 479 DNFs, and 0 errors.
# Attempted 591 of 3000: Found 111 finishers (18.78%), 480 DNFs, and 0 errors.
# Attempted 592 of 3000: Found 112 finishers (18.92%), 480 DNFs, and 0 errors.
# Attempted 593 of 3000: Found 113 finishers (19.06%), 480 DNFs, and 0 errors.
# Attempted 594 of 3000: Found 113 finishers (19.02%), 481 DNFs, and 0 errors.
# Attempted 595 of 3000: Found 113 finishers (18.99%), 482 DNFs, and 0 errors.
# Attempted 596 of 3000: Found 113 finishers (18.96%), 483 DNFs, and 0 errors.
# Attempted 597 of 3000: Found 113 finishers (18.93%), 484 DNFs, and 0 errors.
# Attempted 598 of 3000: Found 113 finishers (18.90%), 485 DNFs, and 0 errors.
# Attempted 599 of 3000: Found 113 finishers (18.86%), 486 DNFs, and 0 errors.
# Attempted 600 of 3000: Found 113 finishers (18.83%), 487 DNFs, and 0 errors.
# Attempted 601 of 3000: Found 113 finishers (18.80%), 488 DNFs, and 0 errors.
# Attempted 602 of 3000: Found 113 finishers (18.77%), 489 DNFs, and 0 errors.
# Attempted 603 of 3000: Found 113 finishers (18.74%), 490 DNFs, and 0 errors.
# Attempted 604 of 3000: Found 114 finishers (18.87%), 490 DNFs, and 0 errors.
# Attempted 605 of 3000: Found 114 finishers (18.84%), 491 DNFs, and 0 errors.
# Attempted 606 of 3000: Found 115 finishers (18.98%), 491 DNFs, and 0 errors.
# Attempted 607 of 3000: Found 115 finishers (18.95%), 492 DNFs, and 0 errors.
# Attempted 608 of 3000: Found 115 finishers (18.91%), 493 DNFs, and 0 errors.
# Attempted 609 of 3000: Found 115 finishers (18.88%), 494 DNFs, and 0 errors.
# Attempted 610 of 3000: Found 115 finishers (18.85%), 495 DNFs, and 0 errors.
# Attempted 611 of 3000: Found 115 finishers (18.82%), 496 DNFs, and 0 errors.
# Attempted 612 of 3000: Found 116 finishers (18.95%), 496 DNFs, and 0 errors.
# Attempted 613 of 3000: Found 116 finishers (18.92%), 497 DNFs, and 0 errors.
# Attempted 614 of 3000: Found 116 finishers (18.89%), 498 DNFs, and 0 errors.
# Attempted 615 of 3000: Found 116 finishers (18.86%), 499 DNFs, and 0 errors.
# Attempted 616 of 3000: Found 116 finishers (18.83%), 500 DNFs, and 0 errors.
# Attempted 617 of 3000: Found 116 finishers (18.80%), 501 DNFs, and 0 errors.
# Attempted 618 of 3000: Found 116 finishers (18.77%), 502 DNFs, and 0 errors.
# Attempted 619 of 3000: Found 117 finishers (18.90%), 502 DNFs, and 0 errors.
# Attempted 620 of 3000: Found 117 finishers (18.87%), 503 DNFs, and 0 errors.
# Attempted 621 of 3000: Found 117 finishers (18.84%), 504 DNFs, and 0 errors.
# Attempted 622 of 3000: Found 118 finishers (18.97%), 504 DNFs, and 0 errors.
# Attempted 623 of 3000: Found 118 finishers (18.94%), 505 DNFs, and 0 errors.
# Attempted 624 of 3000: Found 119 finishers (19.07%), 505 DNFs, and 0 errors.
# Attempted 625 of 3000: Found 119 finishers (19.04%), 506 DNFs, and 0 errors.
# Attempted 626 of 3000: Found 119 finishers (19.01%), 507 DNFs, and 0 errors.
# Attempted 627 of 3000: Found 119 finishers (18.98%), 508 DNFs, and 0 errors.
# Attempted 628 of 3000: Found 120 finishers (19.11%), 508 DNFs, and 0 errors.
# Attempted 629 of 3000: Found 120 finishers (19.08%), 509 DNFs, and 0 errors.
# Attempted 630 of 3000: Found 121 finishers (19.21%), 509 DNFs, and 0 errors.
# Attempted 631 of 3000: Found 121 finishers (19.18%), 510 DNFs, and 0 errors.
# Attempted 632 of 3000: Found 121 finishers (19.15%), 511 DNFs, and 0 errors.
# Attempted 633 of 3000: Found 121 finishers (19.12%), 512 DNFs, and 0 errors.
# Attempted 634 of 3000: Found 121 finishers (19.09%), 513 DNFs, and 0 errors.
# ...
# Attempted 2802 of 3000: Found 543 finishers (19.38%), 2257 DNFs, and 2 errors.
# Attempted 2803 of 3000: Found 544 finishers (19.41%), 2257 DNFs, and 2 errors.
# Attempted 2804 of 3000: Found 544 finishers (19.40%), 2258 DNFs, and 2 errors.
# Attempted 2805 of 3000: Found 544 finishers (19.39%), 2259 DNFs, and 2 errors.
# Attempted 2806 of 3000: Found 544 finishers (19.39%), 2260 DNFs, and 2 errors.
# Attempted 2807 of 3000: Found 545 finishers (19.42%), 2260 DNFs, and 2 errors.
# Attempted 2808 of 3000: Found 545 finishers (19.41%), 2261 DNFs, and 2 errors.
# Attempted 2809 of 3000: Found 545 finishers (19.40%), 2262 DNFs, and 2 errors.
# Attempted 2810 of 3000: Found 545 finishers (19.40%), 2263 DNFs, and 2 errors.
# Attempted 2811 of 3000: Found 545 finishers (19.39%), 2264 DNFs, and 2 errors.
# Attempted 2812 of 3000: Found 545 finishers (19.38%), 2265 DNFs, and 2 errors.
# Attempted 2813 of 3000: Found 546 finishers (19.41%), 2265 DNFs, and 2 errors.
# Attempted 2814 of 3000: Found 546 finishers (19.40%), 2266 DNFs, and 2 errors.
# Attempted 2815 of 3000: Found 546 finishers (19.40%), 2267 DNFs, and 2 errors.
# Attempted 2816 of 3000: Found 546 finishers (19.39%), 2268 DNFs, and 2 errors.
# Attempted 2817 of 3000: Found 546 finishers (19.38%), 2269 DNFs, and 2 errors.
# Attempted 2818 of 3000: Found 546 finishers (19.38%), 2270 DNFs, and 2 errors.
# Attempted 2819 of 3000: Found 547 finishers (19.40%), 2270 DNFs, and 2 errors.
# Attempted 2820 of 3000: Found 548 finishers (19.43%), 2270 DNFs, and 2 errors.
# Attempted 2821 of 3000: Found 548 finishers (19.43%), 2271 DNFs, and 2 errors.
# Attempted 2822 of 3000: Found 549 finishers (19.45%), 2271 DNFs, and 2 errors.
# Attempted 2823 of 3000: Found 549 finishers (19.45%), 2272 DNFs, and 2 errors.
# Attempted 2824 of 3000: Found 549 finishers (19.44%), 2273 DNFs, and 2 errors.
# Attempted 2825 of 3000: Found 549 finishers (19.43%), 2274 DNFs, and 2 errors.
# Attempted 2826 of 3000: Found 550 finishers (19.46%), 2274 DNFs, and 2 errors.
# Attempted 2827 of 3000: Found 551 finishers (19.49%), 2274 DNFs, and 2 errors.
# Attempted 2828 of 3000: Found 551 finishers (19.48%), 2275 DNFs, and 2 errors.
# Attempted 2829 of 3000: Found 551 finishers (19.48%), 2276 DNFs, and 2 errors.
# Attempted 2830 of 3000: Found 551 finishers (19.47%), 2277 DNFs, and 2 errors.
# Attempted 2831 of 3000: Found 551 finishers (19.46%), 2278 DNFs, and 2 errors.
# Attempted 2832 of 3000: Found 551 finishers (19.46%), 2279 DNFs, and 2 errors.
# Attempted 2833 of 3000: Found 551 finishers (19.45%), 2280 DNFs, and 2 errors.
# Attempted 2834 of 3000: Found 551 finishers (19.44%), 2281 DNFs, and 2 errors.
# Attempted 2835 of 3000: Found 552 finishers (19.47%), 2281 DNFs, and 2 errors.
# Attempted 2836 of 3000: Found 552 finishers (19.46%), 2282 DNFs, and 2 errors.
# Attempted 2837 of 3000: Found 552 finishers (19.46%), 2283 DNFs, and 2 errors.
# Attempted 2838 of 3000: Found 552 finishers (19.45%), 2284 DNFs, and 2 errors.
# Attempted 2839 of 3000: Found 552 finishers (19.44%), 2285 DNFs, and 2 errors.
# Attempted 2840 of 3000: Found 553 finishers (19.47%), 2285 DNFs, and 2 errors.
# Attempted 2841 of 3000: Found 554 finishers (19.50%), 2285 DNFs, and 2 errors.
# Attempted 2842 of 3000: Found 555 finishers (19.53%), 2285 DNFs, and 2 errors.
# Attempted 2843 of 3000: Found 556 finishers (19.56%), 2285 DNFs, and 2 errors.
# Attempted 2844 of 3000: Found 557 finishers (19.59%), 2285 DNFs, and 2 errors.
# Attempted 2845 of 3000: Found 557 finishers (19.58%), 2286 DNFs, and 2 errors.
# Attempted 2846 of 3000: Found 557 finishers (19.57%), 2287 DNFs, and 2 errors.
# Attempted 2847 of 3000: Found 557 finishers (19.56%), 2288 DNFs, and 2 errors.
# Attempted 2848 of 3000: Found 558 finishers (19.59%), 2288 DNFs, and 2 errors.
# Attempted 2849 of 3000: Found 558 finishers (19.59%), 2289 DNFs, and 2 errors.
# Attempted 2850 of 3000: Found 559 finishers (19.61%), 2289 DNFs, and 2 errors.
# Attempted 2851 of 3000: Found 559 finishers (19.61%), 2290 DNFs, and 2 errors.
# Attempted 2852 of 3000: Found 559 finishers (19.60%), 2291 DNFs, and 2 errors.
# Attempted 2853 of 3000: Found 559 finishers (19.59%), 2292 DNFs, and 2 errors.
# Attempted 2854 of 3000: Found 560 finishers (19.62%), 2292 DNFs, and 2 errors.
# Attempted 2855 of 3000: Found 560 finishers (19.61%), 2293 DNFs, and 2 errors.
# Attempted 2856 of 3000: Found 560 finishers (19.61%), 2294 DNFs, and 2 errors.
# Attempted 2857 of 3000: Found 560 finishers (19.60%), 2295 DNFs, and 2 errors.
# Attempted 2858 of 3000: Found 560 finishers (19.59%), 2296 DNFs, and 2 errors.
# Attempted 2859 of 3000: Found 560 finishers (19.59%), 2297 DNFs, and 2 errors.
# Attempted 2860 of 3000: Found 561 finishers (19.62%), 2297 DNFs, and 2 errors.
# Attempted 2861 of 3000: Found 561 finishers (19.61%), 2298 DNFs, and 2 errors.
# Attempted 2862 of 3000: Found 561 finishers (19.60%), 2299 DNFs, and 2 errors.
# Attempted 2863 of 3000: Found 561 finishers (19.59%), 2300 DNFs, and 2 errors.
# Attempted 2864 of 3000: Found 561 finishers (19.59%), 2301 DNFs, and 2 errors.
# Attempted 2865 of 3000: Found 561 finishers (19.58%), 2302 DNFs, and 2 errors.
# Attempted 2866 of 3000: Found 562 finishers (19.61%), 2302 DNFs, and 2 errors.
# Attempted 2867 of 3000: Found 562 finishers (19.60%), 2303 DNFs, and 2 errors.
# Attempted 2868 of 3000: Found 563 finishers (19.63%), 2303 DNFs, and 2 errors.
# Attempted 2869 of 3000: Found 563 finishers (19.62%), 2304 DNFs, and 2 errors.
# Attempted 2870 of 3000: Found 563 finishers (19.62%), 2305 DNFs, and 2 errors.
# Attempted 2871 of 3000: Found 563 finishers (19.61%), 2306 DNFs, and 2 errors.
# Attempted 2872 of 3000: Found 563 finishers (19.60%), 2307 DNFs, and 2 errors.
# Attempted 2873 of 3000: Found 563 finishers (19.60%), 2308 DNFs, and 2 errors.
# Attempted 2874 of 3000: Found 563 finishers (19.59%), 2309 DNFs, and 2 errors.
# Attempted 2875 of 3000: Found 563 finishers (19.58%), 2310 DNFs, and 2 errors.
# Attempted 2876 of 3000: Found 563 finishers (19.58%), 2311 DNFs, and 2 errors.
# Attempted 2877 of 3000: Found 563 finishers (19.57%), 2312 DNFs, and 2 errors.
# Attempted 2878 of 3000: Found 564 finishers (19.60%), 2312 DNFs, and 2 errors.
# Attempted 2879 of 3000: Found 564 finishers (19.59%), 2313 DNFs, and 2 errors.
# Attempted 2880 of 3000: Found 564 finishers (19.58%), 2314 DNFs, and 2 errors.
# Attempted 2881 of 3000: Found 564 finishers (19.58%), 2315 DNFs, and 2 errors.
# Attempted 2882 of 3000: Found 565 finishers (19.60%), 2315 DNFs, and 2 errors.
# Attempted 2883 of 3000: Found 566 finishers (19.63%), 2315 DNFs, and 2 errors.
# Attempted 2884 of 3000: Found 567 finishers (19.66%), 2315 DNFs, and 2 errors.
# Attempted 2885 of 3000: Found 567 finishers (19.65%), 2316 DNFs, and 2 errors.
# Attempted 2886 of 3000: Found 567 finishers (19.65%), 2317 DNFs, and 2 errors.
# Attempted 2887 of 3000: Found 567 finishers (19.64%), 2318 DNFs, and 2 errors.
# Attempted 2888 of 3000: Found 567 finishers (19.63%), 2319 DNFs, and 2 errors.
# Attempted 2889 of 3000: Found 567 finishers (19.63%), 2320 DNFs, and 2 errors.
# Attempted 2890 of 3000: Found 567 finishers (19.62%), 2321 DNFs, and 2 errors.
# Attempted 2891 of 3000: Found 567 finishers (19.61%), 2322 DNFs, and 2 errors.
# Attempted 2892 of 3000: Found 567 finishers (19.61%), 2323 DNFs, and 2 errors.
# Attempted 2893 of 3000: Found 567 finishers (19.60%), 2324 DNFs, and 2 errors.
# Attempted 2894 of 3000: Found 567 finishers (19.59%), 2325 DNFs, and 2 errors.
# Attempted 2895 of 3000: Found 567 finishers (19.59%), 2326 DNFs, and 2 errors.
# Attempted 2896 of 3000: Found 568 finishers (19.61%), 2326 DNFs, and 2 errors.
# Attempted 2897 of 3000: Found 568 finishers (19.61%), 2327 DNFs, and 2 errors.
# Attempted 2898 of 3000: Found 568 finishers (19.60%), 2328 DNFs, and 2 errors.
# Attempted 2899 of 3000: Found 568 finishers (19.59%), 2329 DNFs, and 2 errors.
# Attempted 2900 of 3000: Found 568 finishers (19.59%), 2330 DNFs, and 2 errors.
# Attempted 2901 of 3000: Found 569 finishers (19.61%), 2330 DNFs, and 2 errors.
# Attempted 2902 of 3000: Found 569 finishers (19.61%), 2331 DNFs, and 2 errors.
# Attempted 2903 of 3000: Found 569 finishers (19.60%), 2332 DNFs, and 2 errors.
# Attempted 2904 of 3000: Found 569 finishers (19.59%), 2333 DNFs, and 2 errors.
# Attempted 2905 of 3000: Found 569 finishers (19.59%), 2334 DNFs, and 2 errors.
# Attempted 2906 of 3000: Found 569 finishers (19.58%), 2335 DNFs, and 2 errors.
# Attempted 2907 of 3000: Found 569 finishers (19.57%), 2336 DNFs, and 2 errors.
# Attempted 2908 of 3000: Found 569 finishers (19.57%), 2337 DNFs, and 2 errors.
# Attempted 2909 of 3000: Found 569 finishers (19.56%), 2338 DNFs, and 2 errors.
# Attempted 2910 of 3000: Found 570 finishers (19.59%), 2338 DNFs, and 2 errors.
# Attempted 2911 of 3000: Found 570 finishers (19.58%), 2339 DNFs, and 2 errors.
# Attempted 2912 of 3000: Found 570 finishers (19.57%), 2340 DNFs, and 2 errors.
# Attempted 2913 of 3000: Found 570 finishers (19.57%), 2341 DNFs, and 2 errors.
# Attempted 2914 of 3000: Found 570 finishers (19.56%), 2342 DNFs, and 2 errors.
# Attempted 2915 of 3000: Found 570 finishers (19.55%), 2343 DNFs, and 2 errors.
# Attempted 2916 of 3000: Found 570 finishers (19.55%), 2344 DNFs, and 2 errors.
# Attempted 2917 of 3000: Found 570 finishers (19.54%), 2345 DNFs, and 2 errors.
# Attempted 2918 of 3000: Found 570 finishers (19.53%), 2346 DNFs, and 2 errors.
# Attempted 2919 of 3000: Found 570 finishers (19.53%), 2347 DNFs, and 2 errors.
# Attempted 2920 of 3000: Found 570 finishers (19.52%), 2348 DNFs, and 2 errors.
# Attempted 2921 of 3000: Found 570 finishers (19.51%), 2349 DNFs, and 2 errors.
# Attempted 2922 of 3000: Found 570 finishers (19.51%), 2350 DNFs, and 2 errors.
# Attempted 2923 of 3000: Found 570 finishers (19.50%), 2351 DNFs, and 2 errors.
# Attempted 2924 of 3000: Found 570 finishers (19.49%), 2352 DNFs, and 2 errors.
# Attempted 2925 of 3000: Found 570 finishers (19.49%), 2353 DNFs, and 2 errors.
# Attempted 2926 of 3000: Found 570 finishers (19.48%), 2354 DNFs, and 2 errors.
# Attempted 2927 of 3000: Found 570 finishers (19.47%), 2355 DNFs, and 2 errors.
# Attempted 2928 of 3000: Found 570 finishers (19.47%), 2356 DNFs, and 2 errors.
# Attempted 2929 of 3000: Found 570 finishers (19.46%), 2357 DNFs, and 2 errors.
# Attempted 2930 of 3000: Found 570 finishers (19.45%), 2358 DNFs, and 2 errors.
# Attempted 2931 of 3000: Found 570 finishers (19.45%), 2359 DNFs, and 2 errors.
# Attempted 2932 of 3000: Found 571 finishers (19.47%), 2359 DNFs, and 2 errors.
# Attempted 2933 of 3000: Found 572 finishers (19.50%), 2359 DNFs, and 2 errors.
# Attempted 2934 of 3000: Found 572 finishers (19.50%), 2360 DNFs, and 2 errors.
# Attempted 2935 of 3000: Found 572 finishers (19.49%), 2361 DNFs, and 2 errors.
# Attempted 2936 of 3000: Found 572 finishers (19.48%), 2362 DNFs, and 2 errors.
# Attempted 2937 of 3000: Found 572 finishers (19.48%), 2363 DNFs, and 2 errors.
# Attempted 2938 of 3000: Found 572 finishers (19.47%), 2364 DNFs, and 2 errors.
# Attempted 2939 of 3000: Found 572 finishers (19.46%), 2365 DNFs, and 2 errors.
# Attempted 2940 of 3000: Found 572 finishers (19.46%), 2366 DNFs, and 2 errors.
# Attempted 2941 of 3000: Found 572 finishers (19.45%), 2367 DNFs, and 2 errors.
# Attempted 2942 of 3000: Found 572 finishers (19.44%), 2368 DNFs, and 2 errors.
# Attempted 2943 of 3000: Found 572 finishers (19.44%), 2369 DNFs, and 2 errors.
# Attempted 2944 of 3000: Found 572 finishers (19.43%), 2370 DNFs, and 2 errors.
# Attempted 2945 of 3000: Found 573 finishers (19.46%), 2370 DNFs, and 2 errors.
# Attempted 2946 of 3000: Found 573 finishers (19.45%), 2371 DNFs, and 2 errors.
# Attempted 2947 of 3000: Found 573 finishers (19.44%), 2372 DNFs, and 2 errors.
# Attempted 2948 of 3000: Found 574 finishers (19.47%), 2372 DNFs, and 2 errors.
# Attempted 2949 of 3000: Found 574 finishers (19.46%), 2373 DNFs, and 2 errors.
# Attempted 2950 of 3000: Found 574 finishers (19.46%), 2374 DNFs, and 2 errors.
# Attempted 2951 of 3000: Found 574 finishers (19.45%), 2375 DNFs, and 2 errors.
# Attempted 2952 of 3000: Found 574 finishers (19.44%), 2376 DNFs, and 2 errors.
# Attempted 2953 of 3000: Found 574 finishers (19.44%), 2377 DNFs, and 2 errors.
# Attempted 2954 of 3000: Found 574 finishers (19.43%), 2378 DNFs, and 2 errors.
# Attempted 2955 of 3000: Found 574 finishers (19.42%), 2379 DNFs, and 2 errors.
# Attempted 2956 of 3000: Found 574 finishers (19.42%), 2380 DNFs, and 2 errors.
# Attempted 2957 of 3000: Found 574 finishers (19.41%), 2381 DNFs, and 2 errors.
# Attempted 2958 of 3000: Found 574 finishers (19.41%), 2382 DNFs, and 2 errors.
# Attempted 2959 of 3000: Found 574 finishers (19.40%), 2383 DNFs, and 2 errors.
# Attempted 2960 of 3000: Found 574 finishers (19.39%), 2384 DNFs, and 2 errors.
# Attempted 2961 of 3000: Found 574 finishers (19.39%), 2385 DNFs, and 2 errors.
# Attempted 2962 of 3000: Found 575 finishers (19.41%), 2385 DNFs, and 2 errors.
# Attempted 2963 of 3000: Found 575 finishers (19.41%), 2386 DNFs, and 2 errors.
# Attempted 2964 of 3000: Found 575 finishers (19.40%), 2387 DNFs, and 2 errors.
# Attempted 2965 of 3000: Found 575 finishers (19.39%), 2388 DNFs, and 2 errors.
# Attempted 2966 of 3000: Found 575 finishers (19.39%), 2389 DNFs, and 2 errors.
# Attempted 2967 of 3000: Found 575 finishers (19.38%), 2390 DNFs, and 2 errors.
# Attempted 2968 of 3000: Found 575 finishers (19.37%), 2391 DNFs, and 2 errors.
# Attempted 2969 of 3000: Found 575 finishers (19.37%), 2392 DNFs, and 2 errors.
# Attempted 2970 of 3000: Found 576 finishers (19.39%), 2392 DNFs, and 2 errors.
# Attempted 2971 of 3000: Found 576 finishers (19.39%), 2393 DNFs, and 2 errors.
# Attempted 2972 of 3000: Found 577 finishers (19.41%), 2393 DNFs, and 2 errors.
# Attempted 2973 of 3000: Found 577 finishers (19.41%), 2394 DNFs, and 2 errors.
# Attempted 2974 of 3000: Found 577 finishers (19.40%), 2395 DNFs, and 2 errors.
# Attempted 2975 of 3000: Found 577 finishers (19.39%), 2396 DNFs, and 2 errors.
# Attempted 2976 of 3000: Found 578 finishers (19.42%), 2396 DNFs, and 2 errors.
# Attempted 2977 of 3000: Found 578 finishers (19.42%), 2397 DNFs, and 2 errors.
# Attempted 2978 of 3000: Found 578 finishers (19.41%), 2398 DNFs, and 2 errors.
# Attempted 2979 of 3000: Found 579 finishers (19.44%), 2398 DNFs, and 2 errors.
# Attempted 2980 of 3000: Found 579 finishers (19.43%), 2399 DNFs, and 2 errors.
# Attempted 2981 of 3000: Found 579 finishers (19.42%), 2400 DNFs, and 2 errors.
# Attempted 2982 of 3000: Found 579 finishers (19.42%), 2401 DNFs, and 2 errors.
# Attempted 2983 of 3000: Found 579 finishers (19.41%), 2402 DNFs, and 2 errors.
# Attempted 2984 of 3000: Found 579 finishers (19.40%), 2403 DNFs, and 2 errors.
# Attempted 2985 of 3000: Found 579 finishers (19.40%), 2404 DNFs, and 2 errors.
# Attempted 2986 of 3000: Found 580 finishers (19.42%), 2404 DNFs, and 2 errors.
# Attempted 2987 of 3000: Found 580 finishers (19.42%), 2405 DNFs, and 2 errors.
# Attempted 2988 of 3000: Found 581 finishers (19.44%), 2405 DNFs, and 2 errors.
# Attempted 2989 of 3000: Found 582 finishers (19.47%), 2405 DNFs, and 2 errors.
# Attempted 2990 of 3000: Found 582 finishers (19.46%), 2406 DNFs, and 2 errors.
# Attempted 2991 of 3000: Found 582 finishers (19.46%), 2407 DNFs, and 2 errors.
# Attempted 2992 of 3000: Found 582 finishers (19.45%), 2408 DNFs, and 2 errors.
# Attempted 2993 of 3000: Found 582 finishers (19.45%), 2409 DNFs, and 2 errors.
# Attempted 2994 of 3000: Found 582 finishers (19.44%), 2410 DNFs, and 2 errors.
# Attempted 2995 of 3000: Found 582 finishers (19.43%), 2411 DNFs, and 2 errors.
# Attempted 2996 of 3000: Found 582 finishers (19.43%), 2412 DNFs, and 2 errors.
# Attempted 2997 of 3000: Found 582 finishers (19.42%), 2413 DNFs, and 2 errors.
# Attempted 2998 of 3000: Found 582 finishers (19.41%), 2414 DNFs, and 2 errors.
# Attempted 2999 of 3000: Found 582 finishers (19.41%), 2415 DNFs, and 2 errors.
# Attempted 3000 of 3000: Found 582 finishers (19.40%), 2416 DNFs, and 2 errors.
# Loop complete
# 3000 attempts yielded 582 hits (19.40%) with 2 errors.
# Attempted 1 of 2: Found 0 finishers (0.00%), 1 DNFs, and 0 errors.
# Attempted 2 of 2: Found 0 finishers (0.00%), 2 DNFs, and 0 errors.
# Loop complete
# 2 attempts yielded 0 hits (0.00%) with 0 errors.

# %% [markdown]
# # EDA

# %% [markdown]
# ### Convert scraped data to dataframe

# %%
finishers_df = pd.DataFrame(runners)

# %%
finishers_df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 54 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   582 non-null    object
#  1   geo_subregion          582 non-null    object
#  2   country                582 non-null    object
#  3   gender                 582 non-null    object
#  4   age                    582 non-null    object
#  5   bib                    582 non-null    object
#  6   official_time          582 non-null    object
#  7   pace_per_mile          582 non-null    object
#  8   place_overall          582 non-null    object
#  9   place_gender           582 non-null    object
#  10  age_group              582 non-null    object
#  11  place_age-group        582 non-null    object
#  12  country_group          582 non-null    object
#  13  place_country          582 non-null    object
#  14  place_age‐graded       582 non-null    object
#  15  time_age‐graded        582 non-null    object
#  16  percentage_age‐graded  582 non-null    object
#  17  gun_time               582 non-null    object
#  18  gun_place              582 non-null    object
#  19  3m                     581 non-null    object
#  20  5k                     582 non-null    object
#  21  4m                     582 non-null    object
#  22  5m                     580 non-null    object
#  23  6m                     578 non-null    object
#  24  10k                    576 non-null    object
#  25  7m                     581 non-null    object
#  26  8m                     579 non-null    object
#  27  9m                     577 non-null    object
#  28  15k                    580 non-null    object
#  29  10m                    580 non-null    object
#  30  11m                    579 non-null    object
#  31  12m                    579 non-null    object
#  32  20k                    575 non-null    object
#  33  13m                    534 non-null    object
#  34  half                   519 non-null    object
#  35  14m                    559 non-null    object
#  36  15m                    551 non-null    object
#  37  25k                    554 non-null    object
#  38  16m                    552 non-null    object
#  39  17m                    556 non-null    object
#  40  18m                    515 non-null    object
#  41  30k                    491 non-null    object
#  42  19m                    438 non-null    object
#  43  20m                    442 non-null    object
#  44  21m                    492 non-null    object
#  45  35k                    504 non-null    object
#  46  22m                    503 non-null    object
#  47  23m                    432 non-null    object
#  48  24m                    504 non-null    object
#  49  40k                    501 non-null    object
#  50  25m                    534 non-null    object
#  51  26m                    507 non-null    object
#  52  mar                    582 non-null    object
#  53  team                   68 non-null     object
# dtypes: object(54)
# memory usage: 245.7+ KB

# %%
finishers_df
# Out:
#                        name    geo_subregion country gender age    bib  \
# 0          Dina Castellanos         Chetumal     MEX      F  61  72385
# 1             Rajesh Sunder         Lutz, FL     USA      M  44  72665
# 2    Cynthia Marfori-Gordon     New York, NY     USA      F  57  72073
# 3               Nichol Hare     New York, NY     USA      F  40  72512
# 4             Sarath Challa  New Milford, NJ     USA      M  35  72444
# ..                      ...              ...     ...    ...  ..    ...
# 577              Iain Craig         Auckland     NZL      M  55  72531
# 578              Danny Mota     Brooklyn, NY     USA      M  41  72047
# 579          Johnine Barnes   Washington, DC     USA      F  49  72117
# 580            Julie Romain      Buffalo, NY     USA      F  50  72521
# 581         Stephanie Moore    Charlotte, NC     USA      F  34  72548
#
#     official_time pace_per_mile place_overall place_gender  ...      21m  \
# 0         7:11:12         16:27        52,661       22,182  ...  5:41:49
# 1         6:11:36         14:11        49,879       29,372  ...  4:53:51
# 2         7:19:00         16:45        52,824       22,277  ...  5:55:08
# 3         6:28:59         14:51        51,068       21,248  ...  5:10:56
# 4         7:30:37         17:12        53,031       30,620  ...  5:42:02
# ..            ...           ...           ...          ...  ...      ...
# 577       5:56:45         13:37        48,458       28,762  ...  4:45:51
# 578       6:33:56         15:02        51,339       29,948  ...  5:05:45
# 579       6:31:22         14:56        51,203       21,318  ...  5:05:54
# 580       6:49:27         15:37        51,998       21,759  ...  5:20:40
# 581       7:17:21         16:41        52,794       22,261  ...  5:39:05
#
#          35k      22m      23m      24m      40k      25m      26m      mar  \
# 0    5:54:05  5:58:18  6:14:50  6:32:44  6:47:24  6:50:01  7:07:24  7:11:12
# 1    5:05:12  5:08:59  5:24:18  5:39:41  5:52:38  5:54:40  6:08:52  6:11:36
# 2    6:08:34  6:12:36      NaN  6:45:06  6:58:05  7:00:22  7:15:34  7:19:00
# 3    5:22:28  5:25:55  5:42:28  5:57:23  6:09:21  6:11:45  6:25:51  6:28:59
# 4    5:56:48  6:01:44      NaN  6:41:41  6:59:38  7:03:03  7:25:41  7:30:37
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 577  4:55:04  4:58:34  5:11:26  5:25:57  5:38:22  5:40:06  5:53:49  5:56:45
# 578  5:17:30  5:21:47  5:39:31  5:59:04  6:12:02  6:14:46  6:31:02  6:33:56
# 579  5:18:12  5:22:37  5:40:30  5:58:01  6:11:13  6:13:33  6:28:13  6:31:22
# 580  5:33:33  5:37:56  5:55:01  6:12:19  6:26:58  6:29:28  6:46:02  6:49:27
# 581  5:53:05  5:58:00  6:16:36  6:35:58  6:53:17  6:56:24  7:14:09  7:17:21
#
#                       team
# 0                      NaN
# 1                      NaN
# 2    New York Walkers Club
# 3                      NaN
# 4                      NaN
# ..                     ...
# 577                    NaN
# 578                    NaN
# 579        Black Girls Run
# 580                    NaN
# 581                    NaN
#
# [582 rows x 54 columns]

# %% [markdown]
# # Store Data

# %% [markdown]
# ### Write finishers to csv

# %%
def df_to_csv_writer(target_df, destination_file):
    import csv

    # We want to match the order of columns if we are appending new entries to an existing file.
    ### Because we are using a dictionary to capture the race results, and of the way dictionaries are ordered,
    ### It is possible for different scraping runs to attempt to order the columns differently.
    ### That would be confusing, so we force whatever order was established in the first run.
    ### (The bottom line is that it would really be a good idea to use a database here instead.)

    # Try to read the header from the existing file. If they exist, match the column order.
    try:
        with open(destination_file, 'r', encoding="utf-8") as f:
            reader = csv.reader(f)
            header_list = next(reader)
            # It is possible to be missing columns, so check to see if we have everything.
            for x in header_list:
                if x not in target_df.columns:
                    target_df[x] = ''
            target_df = target_df[header_list]
    # If we weren't able to open the file, we are going to create one from scratch.
    except:
        print(f"{destination_file} does not exist, so I'll create it!")

    # This either creates the file, or appends to it without headers. We already took steps to make sure
    # the columns in finishers_df match the headers (if they exist).
    with open(destination_file, 'a', encoding="utf-8") as f:
        target_df.to_csv(f, header=f.tell()==0, index = False, line_terminator = '\n')

# %%
# import csv
# output_csv = "{}{}_{}.csv".format(output_csv_path, race_code, output_csv_name_base)

# # We want to match the order of columns if we are appending new entries to an existing file.
# ### Because we are using a dictionary to capture the race results, and of the way dictionaries are ordered,
# ### It is possible for different scraping runs to attempt to order the columns differently.
# ### That would be confusing, so we force whatever order was established in the first run.
# ### (The bottom line is that it would really be a good idea to use a database here instead.)

# # Try to read the header from the existing file. If they exist, match the column order.
# try:
#     with open(output_csv, 'r', encoding="utf-8") as f:
#         reader = csv.reader(f)
#         header_list = next(reader)
#         # It is possible to be missing columns, so check to see if we have everything.
#         for x in header_list:
#             if x not in finishers_df.columns:
#                 finishers_df[x] = ''
#         finishers_df = finishers_df[header_list]
# # If we weren't able to open the file, we are going to create one from scratch.
# except:
#     print(f"{output_csv} does not exist, so I'll create it!")

# # This either creates the file, or appends to it without headers. We already took steps to make sure
# # the columns in finishers_df match the headers (if they exist).
# with open(output_csv, 'a', encoding="utf-8") as f:
#     finishers_df.to_csv(f, header=f.tell()==0, index = False, line_terminator = '\n')

# %%
# define the path and name for the output file
output_csv = "{}{}_{}.csv".format(output_csv_path, race_code, output_csv_name_base)

df_to_csv_writer(finishers_df, output_csv)

# %% [markdown]
# ### Write scraping log to csv

# %%
log_df = pd.DataFrame(scraping_log)
log_csv = "{}{}_{}.csv".format(log_csv_path, race_code, log_csv_name_base)

# if the file does not exist, create it.
# if the file does exist, append to it without headers.
with open(log_csv, 'a', encoding="utf-8") as f:
    log_df.to_csv(f, header=f.tell()==0, line_terminator = '\n')
