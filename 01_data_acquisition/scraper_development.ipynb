# %% [markdown]
# # Setup

# %% [markdown]
# ### Import Libraries

# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup as bs
import re
import requests
import time
import pandas as pd
import unicodedata

# %% [markdown]
# ### Set URLs

# %%
# base URL for race results
base_url = "https://results.nyrr.org/event/"

# specific races

race_code = "M2019" # 2019 NYC Marathon. includes gun time and splits

# race_code = "20WH5K" # 2020 Washington Heights 5K. 4942 finishers. yes to gun time, no to splits

# race_code = "a70414" # 2007 Brooklyn Half. 4853 finishers. no gun time, no splits

# race_code = "19nyc60" # 2019 NYC 60K. 375 finishers, gun time, no splits

# %% [markdown]
# ### Set File Locations

# %%
# Set path for chromedriver
executable_path = {'chromedriver.exe'}

# Set path for output file

# %% [markdown]
# # Scraping

# %%
# Open browser
browser = Browser('chrome', headless=False)

# %%
# Open website
# website is formed by a base url plus a bib number

# bib numbers for M2019:
bib_number = 6 # US runner, with team affiliation
# bib_number = 9197 # US runner, no team
# bib_number = 5604 # Non-US runner, no team affiliation
# bib_number = 106 # Non-US runner, with team affiliation

# bib numbers for 19nyc60:
# bib_number = 12 # valid
# bib_number = 13 # invalid


# # # special test case: Anonymous runner (no name, no location, no age)
# # # url = "https://results.nyrr.org/event/880625/result/12566474"

url = base_url + race_code + "/result/" + str(bib_number)
browser.visit(url)
time.sleep(1)

# %%
# Detect invalid bib number
# If an invalid bib number is used, the site redirects to the results home page
if browser.url == url:
    print(f"Bib number {bib_number} is valid.")
else:
    print('Redirected.')
# Out:
# Bib number 6 is valid.

# %%
# Scrape page into soup
html = browser.html
soup = bs(html, "html.parser")

# %%
len(soup)
# Out:
# 1

# %% [markdown]
# ## Extracting data

# %% [markdown]
# #### Block 1: Extracting name, location, gender, age, team and bib number
# Basic runner information is contained in a block color-coded to gender.

# %%
# create a dictionary for block 1 items
dict_block_1 = {}

# %%
# find name and location:
# these are both within a clickable area with class 'cursor-pointer results-link'.
# Name is the first child element there.
# Location is the second, and it is formatted as 'sub-location | country',
# where 'sub-location' may be City, ST for locations in the USA, 
# and 'country' is the IAAF country code (https://www.arrs.run/IAAF_CC2.htm)

thangs = soup.find(class_='cursor-pointer results-link').findChildren()
if thangs[0].text:
    print(thangs[0].text)
    dict_block_1['name'] = thangs[0].text
if thangs[1].text:
    print(thangs[1].text.split('|')[0].strip())
    dict_block_1['geo_subdivision'] = thangs[1].text.split('|')[0].strip()
    print(thangs[1].text.split('|')[1].strip())
    dict_block_1['country'] = thangs[1].text.split('|')[1].strip()

dict_block_1
# Out:
# Jared Ward
# Mapleton, UT
# USA
# {'name': 'Jared Ward', 'geo_subdivision': 'Mapleton, UT', 'country': 'USA'}

# %%
# find gender, age, bib number and team:
# these are listed as naked text after a strong tag. Not all runners have a team affiliation, so need to make sure
# we are OK if there is no text after the strong tag.

for thing in soup.find_all('strong'):
    if thing.next_sibling:
        dict_block_1[thing.text.lower()] = thing.next_sibling.strip()
dict_block_1
# Out:
# {'name': 'Jared Ward',
#  'geo_subdivision': 'Mapleton, UT',
#  'country': 'USA',
#  'age/gender': 'M31',
#  'bib': '6',
#  'team ': 'Saucony'}

# %% [markdown]
# #### Block 2: Extracting race outcome data
# Block 2 contains time, pace, place, place by category (ender, age, country), age-graded place and time, and age-graded percentage. Gun time and gun place are included for some, but not all races.

# %%
# create a dictionary for block 2 items
dict_block_2 = {}

# %%
regex_1 = re.compile('.*form-group-item.*')
regex_2 = re.compile('.*ng-hide.*')
block_2_soup = soup.find_all("div", {"class" : regex_1})[:4]
# block_2_soup = soup.find_all("div", {"class" : regex}) # this would get block 3 as well
for spoonful in block_2_soup:
    if spoonful.find("div", {"class" : regex_2}):
        continue
    labels = spoonful.find_all('label')
    values = spoonful.find_all('span', {'class': 'label-value ng-binding'})
    for x in range(0, len(labels)):
        # there was a '\xa0' coming in as part of the 'Place Country' label
        # use unicodedata.normalize to replace that with a space.
        label = unicodedata.normalize("NFKD", labels[x].text)
        print(label, values[x].text)
        dict_block_2[label] = values[x].text
# Out:
# Official Time 2:10:45
# Pace per Mile 05:00
# Place Overall 6
# Place Gender 6
# (30-34) Place Age‐Group 1
# (USA) Place Country 1
# Place Age‐Graded 8
# Time Age‐Graded 2:10:45
# Percentage Age‐Graded 94.04%
# Gun Time 2:10:45
# Gun Place 6

# %%
block_2_soup[1]
# Out:
# <div class="shifting-height row bottom-border form-group-item">
# <div class="col-xs-4 col-sm-4 col-md-4">
# <label>Place Gender</label>
# <span class="label-value ng-binding">6</span>
# <span class="label-value-of ng-binding">of 30,801</span>
# </div>
# <div class="col-xs-4 col-sm-4 col-md-4 no-right-padding-for-mobile" ng-hide="resultDetails.placeAgeGroup == 0">
# <label><span class="less-font-for-mobile ng-binding">(30-34)</span> Place Age‑Group</label>
# <span class="label-value ng-binding">1</span>
# <span class="label-value-of ng-binding">of 4,075</span>
# </div>
# <div class="col-xs-4 col-sm-4 col-md-4" ng-hide="resultDetails.placeAgeGroup == 0">
# <label><span class="less-font-for-mobile ng-binding" ng-show="resultDetails.iaaf">(USA)</span> Place Country</label>
# <span class="label-value ng-binding">1</span>
# <span class="label-value-of ng-binding">of 28,467</span>
# </div>
# </div>

# %%
block_2_soup[2]
# Out:
# <div class="shifting-height row bottom-border form-group-item" ng-hide="resultDetails.placeAgeGrade == 0 &amp;&amp; resultDetails.timeAgeGrade == '0:00:00' &amp;&amp; resultDetails.percentAgeGrade == 0">
# <div class="col-xs-4 col-sm-4 col-md-4">
# <label>Place Age‑Graded</label>
# <span class="label-value ng-binding">8</span>
# <span class="label-value-of ng-binding">of 30,801</span>
# </div>
# <div class="col-xs-4 col-sm-4 col-md-4">
# <label>Time Age‑Graded</label>
# <span class="label-value ng-binding">2:10:45</span>
# </div>
# <div class="col-xs-4 col-sm-4 col-md-4">
# <label>Percentage Age‑Graded</label>
# <span class="label-value ng-binding">94.04%</span>
# </div>
# </div>

# %%
dict_block_2
# Out:
# {'Official Time': '2:10:45',
#  'Pace per Mile': '05:00',
#  'Place Overall': '6',
#  'Place Gender': '6',
#  '(30-34) Place Age‐Group': '1',
#  '(USA) Place Country': '1',
#  'Place Age‐Graded': '8',
#  'Time Age‐Graded': '2:10:45',
#  'Percentage Age‐Graded': '94.04%',
#  'Gun Time': '2:10:45',
#  'Gun Place': '6'}

# %% [markdown]
# #### Block 3: Extracting Splits
# Splits are a more detailed breakdown of the runner's time at checkpoints along the course. Typically, only the longer races have splits. The splits can vary from race to race - it all depends upon where the checkpoints are located.

# %%
# extract split labels and make them into a list
split_labels_soup = soup.find_all('div', {'ng-show': 'resultDetails.splitResults.length > 0'})[0].find_all('label', {'class': 'ng-binding'})

# if this list populates, continue with extracting the splits
if split_labels_soup:
    split_labels = [thing.text for thing in split_labels_soup]

    # extract split values and make them into a list
    split_times_soup = soup.find_all('div', {'ng-show': 'resultDetails.splitResults.length > 0'})[0].find_all('span', {'class': 'label-value ng-binding'})
    split_times = [thing.text for thing in split_times_soup]

    # make a dictionary for the splits
    dict_block_3 = dict(zip(split_labels, split_times))

    print(dict_block_3)

# if the list didn't populate, the race did not have splits.
else:
      print("This race has no splits.")
# Out:
# {'3M': '0:14:46', '5K': '0:15:19', '4M': '0:19:43', '5M': '0:24:37', '6M': '0:29:30', '10K': '0:30:34', '7M': '0:34:26', '8M': '0:39:15', '9M': '0:44:14', '15K': '0:45:46', '10M': '0:49:10', '11M': '0:54:17', '12M': '0:59:08', '20K': '1:01:20', '13M': '1:04:15', 'HALF': '1:04:50', '14M': '1:09:17', '15M': '1:14:23', '25K': '1:17:10', '16M': '1:19:22', '17M': '1:24:17', '18M': '1:29:10', '30K': '1:32:27', '19M': '1:34:14', '20M': '1:39:13', '21M': '1:44:15', '35K': '1:47:57', '22M': '1:49:12', '23M': '1:54:16', '24M': '1:59:35', '40K': '2:03:47', '25M': '2:04:34', '26M': '2:09:37', 'MAR': '2:10:45'}

# %%
# extract distance and date
soup.find_all(class_='sub-title')[0].text
# Out:
# 'Marathon | Nov 3, 2019'

# %%
things = soup.find_all(class_='label-value ng-binding')

# %% [markdown]
# ### Scraping function

# %%
def finisher_scraper(soup):
    finisher_dict = {}
# block 1
    thangs = soup.find(class_='cursor-pointer results-link').findChildren()
    finisher_dict['name'] = thangs[0].text
    finisher_dict['geo_subregion'] = thangs[1].text.split('|')[0].strip()
    finisher_dict['country'] = thangs[1].text.split('|')[1].strip()
    for thing in soup.find_all('strong'):
        if thing.next_sibling:
            pattern = re.compile('[MF][1-9][0-9]?')
            if pattern.match(thing.next_sibling.strip()):
                finisher_dict['gender'] = thing.next_sibling.strip()[0]
                finisher_dict['age'] = thing.next_sibling.strip()[1:]
                continue
            finisher_dict[thing.text.strip().lower().replace(" ", "_").replace("/", "_and_")] = thing.next_sibling.strip()
# block 2
    regex = re.compile('.*form-group-item.*')
#     block_2_soup = soup.find_all("div", {"class" : regex})[:4] # this gets only block 2
    block_2_soup = soup.find_all("div", {"class" : regex}) # this gets block 3 as well
    for spoonful in block_2_soup:
        labels = spoonful.find_all('label')
        values = spoonful.find_all('span', {'class': 'label-value ng-binding'})
        for x in range(0, len(labels)):
            # there was a '\xa0' coming in as part of the 'Place Country' label
            # use unicodedata.normalize to replace that with a space.
            label = unicodedata.normalize("NFKD", labels[x].text)
            if label.endswith("Place Age‐Group"):
                # if we find the place in age-group, add the age group to the dictionary.
                finisher_dict["age_group"] = re.findall(r'\(([^]]*)\)', label)[0]
                label = "Place Age-Group"
            elif label.endswith("Place Country"):
                label = "Place Country"
            finisher_dict[label.strip().lower().replace(" ", "_")] = values[x].text

    return finisher_dict

# %%
# test scraping function
finisher_scraper(soup)
# Out:
# {'name': 'Jared Ward',
#  'geo_subregion': 'Mapleton, UT',
#  'country': 'USA',
#  'gender': 'M',
#  'age': '31',
#  'bib': '6',
#  'team': 'Saucony',
#  'official_time': '2:10:45',
#  'pace_per_mile': '05:00',
#  'place_overall': '6',
#  'place_gender': '6',
#  'age_group': '30-34',
#  'place_age-group': '1',
#  'place_country': '1',
#  'place_age‐graded': '8',
#  'time_age‐graded': '2:10:45',
#  'percentage_age‐graded': '94.04%',
#  'gun_time': '2:10:45',
#  'gun_place': '6',
#  '3m': '0:14:46',
#  '5k': '0:15:19',
#  '4m': '0:19:43',
#  '5m': '0:24:37',
#  '6m': '0:29:30',
#  '10k': '0:30:34',
#  '7m': '0:34:26',
#  '8m': '0:39:15',
#  '9m': '0:44:14',
#  '15k': '0:45:46',
#  '10m': '0:49:10',
#  '11m': '0:54:17',
#  '12m': '0:59:08',
#  '20k': '1:01:20',
#  '13m': '1:04:15',
#  'half': '1:04:50',
#  '14m': '1:09:17',
#  '15m': '1:14:23',
#  '25k': '1:17:10',
#  '16m': '1:19:22',
#  '17m': '1:24:17',
#  '18m': '1:29:10',
#  '30k': '1:32:27',
#  '19m': '1:34:14',
#  '20m': '1:39:13',
#  '21m': '1:44:15',
#  '35k': '1:47:57',
#  '22m': '1:49:12',
#  '23m': '1:54:16',
#  '24m': '1:59:35',
#  '40k': '2:03:47',
#  '25m': '2:04:34',
#  '26m': '2:09:37',
#  'mar': '2:10:45'}

# %% [markdown]
# ### Demonstration Loop

# %%
### Demonstration Loop

# Create lists and dictionaries for results
runners = []
scraping_log = {}

# Open up a browser
browser = Browser('chrome', headless=False)

for bib_number in range(0, 20):
    url = base_url + race_code + "/result/" + str(bib_number)
    browser.visit(url)
    # need a short sleep period to give the site a chance to redirect an invalid bib number.
    # we also don't need to beat on the website too hard.
    time.sleep(3)
#     time.sleep(random.uniform(3,7))
    if browser.url == url:
        try:
            soup = bs(browser.html, "html.parser")
            runners.append(finisher_scraper(soup))
            scraping_log[bib_number] = "success"
        except:
            scraping_log[bib_number] = "scraping error"
    else:
        scraping_log[bib_number] = "DNF"
print('Loop complete')
# Out:
# Loop complete

# %%
len(runners)
# Out:
# 16

# %%
runners
# Out:
# [{'name': 'Shura Kitata',
#   'geo_subregion': 'Addis Ababa',
#   'country': 'ETH',
#   'gender': 'M',
#   'age': '23',
#   'bib': '2',
#   'team': 'NIKE',
#   'official_time': '2:10:39',
#   'pace_per_mile': '04:59',
#   'place_overall': '5',
#   'place_gender': '5',
#   'age_group': '20-24',
#   'place_age-group': '1',
#   'place_country': '3',
#   'place_age‐graded': '7',
#   'time_age‐graded': '2:10:39',
#   'percentage_age‐graded': '94.11%',
#   'gun_time': '2:10:39',
#   'gun_place': '5',
#   '3m': '0:14:48',
#   '5k': '0:15:18',
#   '4m': '0:19:43',
#   '5m': '0:24:36',
#   '6m': '0:29:30',
#   '10k': '0:30:33',
#   '7m': '0:34:22',
#   '8m': '0:39:12',
#   '9m': '0:44:11',
#   '15k': '0:45:44',
#   '10m': '0:49:06',
#   '11m': '0:54:10',
#   '12m': '0:59:05',
#   '20k': '1:01:20',
#   '13m': '1:04:15',
#   'half': '1:04:51',
#   '14m': '1:09:17',
#   '15m': '1:14:22',
#   '25k': '1:17:05',
#   '16m': '1:19:17',
#   '17m': '1:24:16',
#   '18m': '1:29:10',
#   '30k': '1:32:26',
#   '19m': '1:34:13',
#   '20m': '1:39:01',
#   '21m': '1:44:08',
#   '35k': '1:47:37',
#   '22m': '1:48:53',
#   '23m': '1:53:58',
#   '24m': '1:59:21',
#   '40k': '2:03:37',
#   '25m': '2:04:24',
#   '26m': '2:09:33',
#   'mar': '2:10:39'},
#  {'name': 'Geoffrey Kamworor',
#   'geo_subregion': 'Kapchorwa District',
#   'country': 'KEN',
#   'gender': 'M',
#   'age': '26',
#   'bib': '3',
#   'team': 'NIKE',
#   'official_time': '2:08:13',
#   'pace_per_mile': '04:54',
#   'place_overall': '1',
#   'place_gender': '1',
#   'age_group': '25-29',
#   'place_age-group': '1',
#   'place_country': '1',
#   'place_age‐graded': '2',
#   'time_age‐graded': '2:08:13',
#   'percentage_age‐graded': '95.9%',
#   'gun_time': '2:08:13',
#   'gun_place': '1',
#   '3m': '0:14:45',
#   '5k': '0:15:16',
#   '4m': '0:19:42',
#   '5m': '0:24:36',
#   '6m': '0:29:30',
#   '10k': '0:30:35',
#   '7m': '0:34:25',
#   '8m': '0:39:14',
#   '9m': '0:44:14',
#   '15k': '0:45:45',
#   '10m': '0:49:10',
#   '11m': '0:54:17',
#   '12m': '0:59:07',
#   '20k': '1:01:20',
#   '13m': '1:04:15',
#   'half': '1:04:50',
#   '14m': '1:09:16',
#   '15m': '1:14:22',
#   '25k': '1:17:07',
#   '16m': '1:19:17',
#   '17m': '1:24:16',
#   '18m': '1:29:10',
#   '30k': '1:32:25',
#   '19m': '1:34:12',
#   '20m': '1:38:59',
#   '21m': '1:44:07',
#   '35k': '1:47:34',
#   '22m': '1:48:44',
#   '23m': '1:53:20',
#   '24m': '1:57:59',
#   '40k': '2:01:48',
#   '25m': '2:02:30',
#   '26m': '2:07:11',
#   'mar': '2:08:13'},
#  {'name': 'Tamirat Tola',
#   'geo_subregion': 'Addis Ababa',
#   'country': 'ETH',
#   'gender': 'M',
#   'age': '28',
#   'bib': '4',
#   'team': 'adidas',
#   'official_time': '2:09:20',
#   'pace_per_mile': '04:56',
#   'place_overall': '4',
#   'place_gender': '4',
#   'age_group': '25-29',
#   'place_age-group': '4',
#   'place_country': '2',
#   'place_age‐graded': '5',
#   'time_age‐graded': '2:09:20',
#   'percentage_age‐graded': '95.07%',
#   'gun_time': '2:09:20',
#   'gun_place': '4',
#   '3m': '0:14:49',
#   '5k': '0:15:21',
#   '4m': '0:19:44',
#   '5m': '0:24:37',
#   '6m': '0:29:28',
#   '10k': '0:30:34',
#   '7m': '0:34:20',
#   '8m': '0:39:13',
#   '9m': '0:44:15',
#   '15k': '0:45:45',
#   '10m': '0:49:10',
#   '11m': '0:54:17',
#   '12m': '0:59:08',
#   '20k': '1:01:20',
#   '13m': '1:04:15',
#   'half': '1:04:50',
#   '14m': '1:09:17',
#   '15m': '1:14:21',
#   '25k': '1:17:05',
#   '16m': '1:19:17',
#   '17m': '1:24:16',
#   '18m': '1:29:10',
#   '30k': '1:32:26',
#   '19m': '1:34:13',
#   '20m': '1:39:00',
#   '21m': '1:44:07',
#   '35k': '1:47:35',
#   '22m': '1:48:43',
#   '23m': '1:53:21',
#   '24m': '1:58:25',
#   '40k': '2:02:29',
#   '25m': '2:03:15',
#   '26m': '2:08:13',
#   'mar': '2:09:20'},
#  {'name': 'Albert Korir',
#   'geo_subregion': 'Kapkitony',
#   'country': 'KEN',
#   'gender': 'M',
#   'age': '25',
#   'bib': '5',
#   'team': 'adidas',
#   'official_time': '2:08:36',
#   'pace_per_mile': '04:55',
#   'place_overall': '2',
#   'place_gender': '2',
#   'age_group': '25-29',
#   'place_age-group': '2',
#   'place_country': '2',
#   'place_age‐graded': '3',
#   'time_age‐graded': '2:08:36',
#   'percentage_age‐graded': '95.62%',
#   'gun_time': '2:08:36',
#   'gun_place': '2',
#   '3m': '0:14:47',
#   '5k': '0:15:18',
#   '4m': '0:19:43',
#   '5m': '0:24:36',
#   '6m': '0:29:28',
#   '10k': '0:30:33',
#   '7m': '0:34:23',
#   '8m': '0:39:13',
#   '9m': '0:44:13',
#   '15k': '0:45:44',
#   '10m': '0:49:10',
#   '11m': '0:54:16',
#   '12m': '0:59:08',
#   '20k': '1:01:19',
#   '13m': '1:04:14',
#   'half': '1:04:49',
#   '14m': '1:09:17',
#   '15m': '1:14:21',
#   '25k': '1:17:06',
#   '16m': '1:19:16',
#   '17m': '1:24:17',
#   '18m': '1:29:10',
#   '30k': '1:32:25',
#   '19m': '1:34:12',
#   '20m': '1:39:00',
#   '21m': '1:44:08',
#   '35k': '1:47:35',
#   '22m': '1:48:44',
#   '23m': '1:53:20',
#   '24m': '1:58:06',
#   '40k': '2:02:00',
#   '25m': '2:02:44',
#   '26m': '2:07:32',
#   'mar': '2:08:36'},
#  {'name': 'Jared Ward',
#   'geo_subregion': 'Mapleton, UT',
#   'country': 'USA',
#   'gender': 'M',
#   'age': '31',
#   'bib': '6',
#   'team': 'Saucony',
#   'official_time': '2:10:45',
#   'pace_per_mile': '05:00',
#   'place_overall': '6',
#   'place_gender': '6',
#   'age_group': '30-34',
#   'place_age-group': '1',
#   'place_country': '1',
#   'place_age‐graded': '8',
#   'time_age‐graded': '2:10:45',
#   'percentage_age‐graded': '94.04%',
#   'gun_time': '2:10:45',
#   'gun_place': '6',
#   '3m': '0:14:46',
#   '5k': '0:15:19',
#   '4m': '0:19:43',
#   '5m': '0:24:37',
#   '6m': '0:29:30',
#   '10k': '0:30:34',
#   '7m': '0:34:26',
#   '8m': '0:39:15',
#   '9m': '0:44:14',
#   '15k': '0:45:46',
#   '10m': '0:49:10',
#   '11m': '0:54:17',
#   '12m': '0:59:08',
#   '20k': '1:01:20',
#   '13m': '1:04:15',
#   'half': '1:04:50',
#   '14m': '1:09:17',
#   '15m': '1:14:23',
#   '25k': '1:17:10',
#   '16m': '1:19:22',
#   '17m': '1:24:17',
#   '18m': '1:29:10',
#   '30k': '1:32:27',
#   '19m': '1:34:14',
#   '20m': '1:39:13',
#   '21m': '1:44:15',
#   '35k': '1:47:57',
#   '22m': '1:49:12',
#   '23m': '1:54:16',
#   '24m': '1:59:35',
#   '40k': '2:03:47',
#   '25m': '2:04:34',
#   '26m': '2:09:37',
#   'mar': '2:10:45'},
#  {'name': 'Michel Butter',
#   'geo_subregion': 'Castricum',
#   'country': 'NLD',
#   'gender': 'M',
#   'age': '33',
#   'bib': '7',
#   'team': 'New Balance',
#   'official_time': '2:25:06',
#   'pace_per_mile': '05:33',
#   'place_overall': '37',
#   'place_gender': '35',
#   'age_group': '30-34',
#   'place_age-group': '15',
#   'place_country': '1',
#   'place_age‐graded': '61',
#   'time_age‐graded': '2:24:55',
#   'percentage_age‐graded': '84.84%',
#   'gun_time': '2:25:06',
#   'gun_place': '37',
#   '3m': '0:14:48',
#   '5k': '0:15:18',
#   '4m': '0:19:44',
#   '5m': '0:24:37',
#   '6m': '0:29:29',
#   '10k': '0:30:36',
#   '7m': '0:34:25',
#   '8m': '0:39:17',
#   '9m': '0:44:15',
#   '15k': '0:45:47',
#   '10m': '0:49:11',
#   '11m': '0:54:18',
#   '12m': '0:59:11',
#   '20k': '1:01:25',
#   '13m': '1:04:25',
#   'half': '1:05:05',
#   '14m': '1:09:40',
#   '15m': '1:15:22',
#   '25k': '1:18:42',
#   '16m': '1:21:11',
#   '17m': '1:26:33',
#   '18m': '1:32:02',
#   '30k': '1:35:46',
#   '19m': '1:37:50',
#   '20m': '1:43:56',
#   '21m': '1:50:22',
#   '35k': '1:55:04',
#   '22m': '1:56:42',
#   '23m': '2:03:26',
#   '24m': '2:10:32',
#   '40k': '2:16:06',
#   '25m': '2:17:07',
#   '26m': '2:23:41',
#   'mar': '2:25:06'},
#  {'name': 'Brett Robinson',
#   'geo_subregion': 'Melbourne',
#   'country': 'AUS',
#   'gender': 'M',
#   'age': '28',
#   'bib': '8',
#   'team': 'NIKE',
#   'official_time': '2:17:50',
#   'pace_per_mile': '05:16',
#   'place_overall': '23',
#   'place_gender': '23',
#   'age_group': '25-29',
#   'place_age-group': '11',
#   'place_country': '2',
#   'place_age‐graded': '29',
#   'time_age‐graded': '2:17:50',
#   'percentage_age‐graded': '89.21%',
#   'gun_time': '2:17:50',
#   'gun_place': '23',
#   '3m': '0:14:47',
#   '5k': '0:15:17',
#   '4m': '0:19:43',
#   '5m': '0:24:35',
#   '6m': '0:29:30',
#   '10k': '0:30:34',
#   '7m': '0:34:26',
#   '8m': '0:39:15',
#   '9m': '0:44:15',
#   '15k': '0:45:46',
#   '10m': '0:49:10',
#   '11m': '0:54:17',
#   '12m': '0:59:08',
#   '20k': '1:01:20',
#   '13m': '1:04:15',
#   'half': '1:04:50',
#   '14m': '1:09:16',
#   '15m': '1:14:13',
#   '25k': '1:17:02',
#   '16m': '1:19:19',
#   '17m': '1:24:17',
#   '18m': '1:29:10',
#   '30k': '1:32:28',
#   '19m': '1:34:18',
#   '20m': '1:39:52',
#   '21m': '1:45:24',
#   '35k': '1:49:30',
#   '22m': '1:50:56',
#   '23m': '1:56:46',
#   '24m': '2:02:54',
#   '40k': '2:08:26',
#   '25m': '2:09:27',
#   '26m': '2:16:21',
#   'mar': '2:17:50'},
#  {'name': 'Jack Rayner',
#   'geo_subregion': 'Melbourne',
#   'country': 'AUS',
#   'gender': 'M',
#   'age': '23',
#   'bib': '9',
#   'team': 'NIKE',
#   'official_time': '2:16:58',
#   'pace_per_mile': '05:14',
#   'place_overall': '22',
#   'place_gender': '22',
#   'age_group': '20-24',
#   'place_age-group': '3',
#   'place_country': '1',
#   'place_age‐graded': '27',
#   'time_age‐graded': '2:16:58',
#   'percentage_age‐graded': '89.77%',
#   'gun_time': '2:16:58',
#   'gun_place': '22',
#   '3m': '0:14:45',
#   '5k': '0:15:19',
#   '4m': '0:19:43',
#   '5m': '0:24:37',
#   '6m': '0:29:30',
#   '10k': '0:30:32',
#   '7m': '0:34:27',
#   '8m': '0:39:18',
#   '9m': '0:44:15',
#   '15k': '0:45:47',
#   '10m': '0:49:11',
#   '11m': '0:54:18',
#   '12m': '0:59:11',
#   '20k': '1:01:22',
#   '13m': '1:04:16',
#   'half': '1:04:51',
#   '14m': '1:09:18',
#   '15m': '1:14:27',
#   '25k': '1:17:21',
#   '16m': '1:19:41',
#   '17m': '1:24:46',
#   '18m': '1:29:58',
#   '30k': '1:33:25',
#   '19m': '1:35:23',
#   '20m': '1:40:59',
#   '21m': '1:46:40',
#   '35k': '1:50:55',
#   '22m': '1:52:22',
#   '23m': '1:58:10',
#   '24m': '2:04:07',
#   '40k': '2:08:58',
#   '25m': '2:09:51',
#   '26m': '2:15:39',
#   'mar': '2:16:58'},
#  {'name': 'Stephen Sambu',
#   'geo_subregion': 'Tucson, AZ',
#   'country': 'USA',
#   'gender': 'M',
#   'age': '31',
#   'bib': '10',
#   'team': 'NIKE',
#   'official_time': '2:11:11',
#   'pace_per_mile': '05:01',
#   'place_overall': '7',
#   'place_gender': '7',
#   'age_group': '30-34',
#   'place_age-group': '2',
#   'place_country': '3',
#   'place_age‐graded': '10',
#   'time_age‐graded': '2:11:11',
#   'percentage_age‐graded': '93.73%',
#   'gun_time': '2:11:11',
#   'gun_place': '7',
#   '3m': '0:14:47',
#   '5k': '0:15:19',
#   '4m': '0:19:44',
#   '5m': '0:24:37',
#   '6m': '0:29:30',
#   '10k': '0:30:32',
#   '7m': '0:34:25',
#   '8m': '0:39:14',
#   '9m': '0:44:13',
#   '15k': '0:45:45',
#   '10m': '0:49:10',
#   '11m': '0:54:16',
#   '12m': '0:59:08',
#   '20k': '1:01:20',
#   '13m': '1:04:15',
#   'half': '1:04:50',
#   '14m': '1:09:17',
#   '15m': '1:14:23',
#   '25k': '1:17:06',
#   '16m': '1:19:19',
#   '17m': '1:24:16',
#   '18m': '1:29:10',
#   '30k': '1:32:27',
#   '19m': '1:34:13',
#   '20m': '1:39:12',
#   '21m': '1:44:15',
#   '35k': '1:47:58',
#   '22m': '1:49:13',
#   '23m': '1:54:16',
#   '24m': '1:59:39',
#   '40k': '2:03:59',
#   '25m': '2:04:46',
#   '26m': '2:09:58',
#   'mar': '2:11:11'},
#  {'name': 'Yoshiki Takenouchi',
#   'geo_subregion': 'Kyoto',
#   'country': 'JPN',
#   'gender': 'M',
#   'age': '27',
#   'bib': '11',
#   'team': 'NTT West',
#   'official_time': '2:11:18',
#   'pace_per_mile': '05:01',
#   'place_overall': '8',
#   'place_gender': '8',
#   'age_group': '25-29',
#   'place_age-group': '5',
#   'place_country': '1',
#   'place_age‐graded': '11',
#   'time_age‐graded': '2:11:18',
#   'percentage_age‐graded': '93.64%',
#   'gun_time': '2:11:18',
#   'gun_place': '8',
#   '3m': '0:14:48',
#   '5k': '0:15:20',
#   '4m': '0:19:44',
#   '5m': '0:24:37',
#   '6m': '0:29:30',
#   '10k': '0:30:35',
#   '7m': '0:34:26',
#   '8m': '0:39:16',
#   '9m': '0:44:14',
#   '15k': '0:45:45',
#   '10m': '0:49:11',
#   '11m': '0:54:17',
#   '12m': '0:59:08',
#   '20k': '1:01:20',
#   '13m': '1:04:15',
#   'half': '1:04:49',
#   '14m': '1:09:17',
#   '15m': '1:14:22',
#   '25k': '1:17:06',
#   '16m': '1:19:18',
#   '17m': '1:24:16',
#   '18m': '1:29:10',
#   '30k': '1:32:26',
#   '19m': '1:34:13',
#   '20m': '1:39:13',
#   '21m': '1:44:15',
#   '35k': '1:48:00',
#   '22m': '1:49:18',
#   '23m': '1:54:27',
#   '24m': '1:59:50',
#   '40k': '2:04:09',
#   '25m': '2:04:56',
#   '26m': '2:10:11',
#   'mar': '2:11:18'},
#  {'name': 'Arne Gabius',
#   'geo_subregion': 'Stuttgart',
#   'country': 'DEU',
#   'gender': 'M',
#   'age': '38',
#   'bib': '12',
#   'team': 'NIKE',
#   'official_time': '2:12:57',
#   'pace_per_mile': '05:05',
#   'place_overall': '11',
#   'place_gender': '11',
#   'age_group': '35-39',
#   'place_age-group': '1',
#   'place_country': '1',
#   'place_age‐graded': '6',
#   'time_age‐graded': '2:10:33',
#   'percentage_age‐graded': '94.18%',
#   'gun_time': '2:12:57',
#   'gun_place': '11',
#   '3m': '0:14:48',
#   '5k': '0:15:18',
#   '4m': '0:19:43',
#   '5m': '0:24:37',
#   '6m': '0:29:30',
#   '10k': '0:30:35',
#   '7m': '0:34:26',
#   '8m': '0:39:16',
#   '9m': '0:44:14',
#   '15k': '0:45:46',
#   '10m': '0:49:10',
#   '11m': '0:54:17',
#   '12m': '0:59:09',
#   '20k': '1:01:21',
#   '13m': '1:04:15',
#   'half': '1:04:52',
#   '14m': '1:09:17',
#   '15m': '1:14:26',
#   '25k': '1:17:25',
#   '16m': '1:19:42',
#   '17m': '1:24:45',
#   '18m': '1:29:47',
#   '30k': '1:33:09',
#   '19m': '1:35:00',
#   '20m': '1:40:16',
#   '21m': '1:45:33',
#   '35k': '1:49:27',
#   '22m': '1:50:49',
#   '23m': '1:56:10',
#   '24m': '2:01:43',
#   '40k': '2:05:56',
#   '25m': '2:06:43',
#   '26m': '2:11:51',
#   'mar': '2:12:57'},
#  {'name': 'Abdi Abdirahman',
#   'geo_subregion': 'Tucson, AZ',
#   'country': 'USA',
#   'gender': 'M',
#   'age': '42',
#   'bib': '14',
#   'team': 'NIKE',
#   'official_time': '2:11:34',
#   'pace_per_mile': '05:02',
#   'place_overall': '9',
#   'place_gender': '9',
#   'age_group': '40-44',
#   'place_age-group': '1',
#   'place_country': '2',
#   'place_age‐graded': '1',
#   'time_age‐graded': '2:05:34',
#   'percentage_age‐graded': '97.92%',
#   'gun_time': '2:11:34',
#   'gun_place': '9',
#   '3m': '0:14:47',
#   '5k': '0:15:19',
#   '4m': '0:19:44',
#   '5m': '0:24:36',
#   '6m': '0:29:31',
#   '10k': '0:30:36',
#   '7m': '0:34:27',
#   '8m': '0:39:18',
#   '9m': '0:44:14',
#   '15k': '0:45:45',
#   '10m': '0:49:10',
#   '11m': '0:54:17',
#   '12m': '0:59:09',
#   '20k': '1:01:22',
#   '13m': '1:04:15',
#   'half': '1:04:50',
#   '14m': '1:09:18',
#   '15m': '1:14:23',
#   '25k': '1:17:09',
#   '16m': '1:19:25',
#   '17m': '1:24:18',
#   '18m': '1:29:10',
#   '30k': '1:32:28',
#   '19m': '1:34:15',
#   '20m': '1:39:13',
#   '21m': '1:44:15',
#   '35k': '1:47:59',
#   '22m': '1:49:18',
#   '23m': '1:54:29',
#   '24m': '1:59:54',
#   '40k': '2:04:19',
#   '25m': '2:05:07',
#   '26m': '2:10:23',
#   'mar': '2:11:34'},
#  {'name': 'Daniel Mesfun',
#   'geo_subregion': 'Flagstaff, AZ',
#   'country': 'USA',
#   'gender': 'M',
#   'age': '31',
#   'bib': '15',
#   'official_time': '2:13:09',
#   'pace_per_mile': '05:05',
#   'place_overall': '12',
#   'place_gender': '12',
#   'age_group': '30-34',
#   'place_age-group': '3',
#   'place_country': '1',
#   'place_age‐graded': '13',
#   'time_age‐graded': '2:13:09',
#   'percentage_age‐graded': '92.34%',
#   'gun_time': '2:13:09',
#   'gun_place': '12',
#   '3m': '0:14:49',
#   '5k': '0:15:20',
#   '4m': '0:19:44',
#   '5m': '0:24:38',
#   '6m': '0:29:30',
#   '10k': '0:30:36',
#   '7m': '0:34:28',
#   '8m': '0:39:17',
#   '9m': '0:44:15',
#   '15k': '0:45:47',
#   '10m': '0:49:11',
#   '11m': '0:54:17',
#   '12m': '0:59:09',
#   '20k': '1:01:22',
#   '13m': '1:04:15',
#   'half': '1:04:50',
#   '14m': '1:09:17',
#   '15m': '1:14:23',
#   '25k': '1:17:08',
#   '16m': '1:19:21',
#   '17m': '1:24:17',
#   '18m': '1:29:10',
#   '30k': '1:32:27',
#   '19m': '1:34:13',
#   '20m': '1:39:14',
#   '21m': '1:44:16',
#   '35k': '1:47:59',
#   '22m': '1:49:18',
#   '23m': '1:54:34',
#   '24m': '2:00:21',
#   '40k': '2:05:07',
#   '25m': '2:05:59',
#   '26m': '2:11:45',
#   'mar': '2:13:09'},
#  {'name': 'Tyler McCandless',
#   'geo_subregion': 'Boulder, CO',
#   'country': 'USA',
#   'gender': 'M',
#   'age': '33',
#   'bib': '16',
#   'team': 'Altra Running',
#   'official_time': '2:21:55',
#   'pace_per_mile': '05:25',
#   'place_overall': '29',
#   'place_gender': '29',
#   'age_group': '30-34',
#   'place_age-group': '11',
#   'place_country': '11',
#   'place_age‐graded': '41',
#   'time_age‐graded': '2:21:45',
#   'percentage_age‐graded': '86.75%',
#   'gun_time': '2:21:55',
#   'gun_place': '29',
#   '3m': '0:15:39',
#   '5k': '0:16:12',
#   '4m': '0:20:44',
#   '5m': '0:25:45',
#   '6m': '0:30:44',
#   '10k': '0:31:51',
#   '7m': '0:35:46',
#   '8m': '0:40:55',
#   '9m': '0:46:02',
#   '15k': '0:47:38',
#   '10m': '0:51:04',
#   '11m': '0:56:18',
#   '12m': '1:01:17',
#   '20k': '1:03:32',
#   '13m': '1:06:28',
#   'half': '1:07:03',
#   '14m': '1:11:35',
#   '15m': '1:16:55',
#   '25k': '1:19:57',
#   '16m': '1:22:18',
#   '17m': '1:27:26',
#   '18m': '1:32:34',
#   '30k': '1:36:03',
#   '19m': '1:38:00',
#   '20m': '1:43:37',
#   '21m': '1:49:32',
#   '35k': '1:54:02',
#   '22m': '1:55:36',
#   '23m': '2:01:45',
#   '24m': '2:08:13',
#   '40k': '2:13:33',
#   '25m': '2:14:30',
#   '26m': '2:20:38',
#   'mar': '2:21:55'},
#  {'name': 'Tyler Pennel',
#   'geo_subregion': 'Blowing Rock, NC',
#   'country': 'USA',
#   'gender': 'M',
#   'age': '31',
#   'bib': '18',
#   'team': 'on ZAP Endurance',
#   'official_time': '2:14:10',
#   'pace_per_mile': '05:08',
#   'place_overall': '14',
#   'place_gender': '14',
#   'age_group': '30-34',
#   'place_age-group': '5',
#   'place_country': '4',
#   'place_age‐graded': '15',
#   'time_age‐graded': '2:14:10',
#   'percentage_age‐graded': '91.64%',
#   'gun_time': '2:14:10',
#   'gun_place': '14',
#   '3m': '0:15:37',
#   '5k': '0:16:12',
#   '4m': '0:20:45',
#   '5m': '0:25:45',
#   '6m': '0:30:44',
#   '10k': '0:31:51',
#   '7m': '0:35:46',
#   '8m': '0:40:55',
#   '9m': '0:46:02',
#   '15k': '0:47:38',
#   '10m': '0:51:04',
#   '11m': '0:56:17',
#   '12m': '1:01:17',
#   '20k': '1:03:31',
#   '13m': '1:06:20',
#   'half': '1:06:55',
#   '14m': '1:11:23',
#   '15m': '1:16:37',
#   '25k': '1:19:34',
#   '16m': '1:21:56',
#   '17m': '1:26:59',
#   '18m': '1:31:59',
#   '30k': '1:35:17',
#   '19m': '1:37:04',
#   '20m': '1:42:12',
#   '21m': '1:47:22',
#   '35k': '1:51:06',
#   '22m': '1:52:21',
#   '23m': '1:57:27',
#   '24m': '2:02:52',
#   '40k': '2:07:04',
#   '25m': '2:07:50',
#   '26m': '2:13:00',
#   'mar': '2:14:10'},
#  {'name': 'Tyler Jermann',
#   'geo_subregion': 'Burnsville, MN',
#   'country': 'USA',
#   'gender': 'M',
#   'age': '27',
#   'bib': '19',
#   'team': 'Team USA Minnesota',
#   'official_time': '2:15:38',
#   'pace_per_mile': '05:11',
#   'place_overall': '18',
#   'place_gender': '18',
#   'age_group': '25-29',
#   'place_age-group': '8',
#   'place_country': '6',
#   'place_age‐graded': '22',
#   'time_age‐graded': '2:15:38',
#   'percentage_age‐graded': '90.66%',
#   'gun_time': '2:15:38',
#   'gun_place': '18',
#   '3m': '0:15:40',
#   '5k': '0:16:13',
#   '4m': '0:20:46',
#   '5m': '0:25:49',
#   '6m': '0:30:54',
#   '10k': '0:32:00',
#   '7m': '0:36:02',
#   '8m': '0:41:13',
#   '9m': '0:46:26',
#   '15k': '0:48:01',
#   '10m': '0:51:29',
#   '11m': '0:56:45',
#   '12m': '1:01:47',
#   '20k': '1:04:00',
#   '13m': '1:06:58',
#   'half': '1:07:33',
#   '14m': '1:12:03',
#   '15m': '1:17:18',
#   '25k': '1:20:11',
#   '16m': '1:22:32',
#   '17m': '1:27:31',
#   '18m': '1:32:32',
#   '30k': '1:35:49',
#   '19m': '1:37:37',
#   '20m': '1:42:46',
#   '21m': '1:48:00',
#   '35k': '1:51:50',
#   '22m': '1:53:14',
#   '23m': '1:58:23',
#   '24m': '2:03:51',
#   '40k': '2:08:18',
#   '25m': '2:09:07',
#   '26m': '2:14:28',
#   'mar': '2:15:38'}]

# %%
scraping_log
# Out:
# {0: 'DNF',
#  1: 'DNF',
#  2: 'success',
#  3: 'success',
#  4: 'success',
#  5: 'success',
#  6: 'success',
#  7: 'success',
#  8: 'success',
#  9: 'success',
#  10: 'success',
#  11: 'success',
#  12: 'success',
#  13: 'DNF',
#  14: 'success',
#  15: 'success',
#  16: 'success',
#  17: 'DNF',
#  18: 'success',
#  19: 'success'}

# %%
df = pd.DataFrame(runners)

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 53 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   16 non-null     object
#  1   geo_subregion          16 non-null     object
#  2   country                16 non-null     object
#  3   gender                 16 non-null     object
#  4   age                    16 non-null     object
#  5   bib                    16 non-null     object
#  6   team                   15 non-null     object
#  7   official_time          16 non-null     object
#  8   pace_per_mile          16 non-null     object
#  9   place_overall          16 non-null     object
#  10  place_gender           16 non-null     object
#  11  age_group              16 non-null     object
#  12  place_age-group        16 non-null     object
#  13  place_country          16 non-null     object
#  14  place_age‐graded       16 non-null     object
#  15  time_age‐graded        16 non-null     object
#  16  percentage_age‐graded  16 non-null     object
#  17  gun_time               16 non-null     object
#  18  gun_place              16 non-null     object
#  19  3m                     16 non-null     object
#  20  5k                     16 non-null     object
#  21  4m                     16 non-null     object
#  22  5m                     16 non-null     object
#  23  6m                     16 non-null     object
#  24  10k                    16 non-null     object
#  25  7m                     16 non-null     object
#  26  8m                     16 non-null     object
#  27  9m                     16 non-null     object
#  28  15k                    16 non-null     object
#  29  10m                    16 non-null     object
#  30  11m                    16 non-null     object
#  31  12m                    16 non-null     object
#  32  20k                    16 non-null     object
#  33  13m                    16 non-null     object
#  34  half                   16 non-null     object
#  35  14m                    16 non-null     object
#  36  15m                    16 non-null     object
#  37  25k                    16 non-null     object
#  38  16m                    16 non-null     object
#  39  17m                    16 non-null     object
#  40  18m                    16 non-null     object
#  41  30k                    16 non-null     object
#  42  19m                    16 non-null     object
#  43  20m                    16 non-null     object
#  44  21m                    16 non-null     object
#  45  35k                    16 non-null     object
#  46  22m                    16 non-null     object
#  47  23m                    16 non-null     object
#  48  24m                    16 non-null     object
#  49  40k                    16 non-null     object
#  50  25m                    16 non-null     object
#  51  26m                    16 non-null     object
#  52  mar                    16 non-null     object
# dtypes: object(53)
# memory usage: 6.8+ KB

# %%
df
# Out:
#                   name       geo_subregion country gender age bib  \
# 0         Shura Kitata         Addis Ababa     ETH      M  23   2
# 1    Geoffrey Kamworor  Kapchorwa District     KEN      M  26   3
# 2         Tamirat Tola         Addis Ababa     ETH      M  28   4
# 3         Albert Korir           Kapkitony     KEN      M  25   5
# 4           Jared Ward        Mapleton, UT     USA      M  31   6
# 5        Michel Butter           Castricum     NLD      M  33   7
# 6       Brett Robinson           Melbourne     AUS      M  28   8
# 7          Jack Rayner           Melbourne     AUS      M  23   9
# 8        Stephen Sambu          Tucson, AZ     USA      M  31  10
# 9   Yoshiki Takenouchi               Kyoto     JPN      M  27  11
# 10         Arne Gabius           Stuttgart     DEU      M  38  12
# 11     Abdi Abdirahman          Tucson, AZ     USA      M  42  14
# 12       Daniel Mesfun       Flagstaff, AZ     USA      M  31  15
# 13    Tyler McCandless         Boulder, CO     USA      M  33  16
# 14        Tyler Pennel    Blowing Rock, NC     USA      M  31  18
# 15       Tyler Jermann      Burnsville, MN     USA      M  27  19
#
#                   team official_time pace_per_mile place_overall  ...  \
# 0                 NIKE       2:10:39         04:59             5  ...
# 1                 NIKE       2:08:13         04:54             1  ...
# 2               adidas       2:09:20         04:56             4  ...
# 3               adidas       2:08:36         04:55             2  ...
# 4              Saucony       2:10:45         05:00             6  ...
# 5          New Balance       2:25:06         05:33            37  ...
# 6                 NIKE       2:17:50         05:16            23  ...
# 7                 NIKE       2:16:58         05:14            22  ...
# 8                 NIKE       2:11:11         05:01             7  ...
# 9             NTT West       2:11:18         05:01             8  ...
# 10                NIKE       2:12:57         05:05            11  ...
# 11                NIKE       2:11:34         05:02             9  ...
# 12                 NaN       2:13:09         05:05            12  ...
# 13       Altra Running       2:21:55         05:25            29  ...
# 14    on ZAP Endurance       2:14:10         05:08            14  ...
# 15  Team USA Minnesota       2:15:38         05:11            18  ...
#
#         20m      21m      35k      22m      23m      24m      40k      25m  \
# 0   1:39:01  1:44:08  1:47:37  1:48:53  1:53:58  1:59:21  2:03:37  2:04:24
# 1   1:38:59  1:44:07  1:47:34  1:48:44  1:53:20  1:57:59  2:01:48  2:02:30
# 2   1:39:00  1:44:07  1:47:35  1:48:43  1:53:21  1:58:25  2:02:29  2:03:15
# 3   1:39:00  1:44:08  1:47:35  1:48:44  1:53:20  1:58:06  2:02:00  2:02:44
# 4   1:39:13  1:44:15  1:47:57  1:49:12  1:54:16  1:59:35  2:03:47  2:04:34
# 5   1:43:56  1:50:22  1:55:04  1:56:42  2:03:26  2:10:32  2:16:06  2:17:07
# 6   1:39:52  1:45:24  1:49:30  1:50:56  1:56:46  2:02:54  2:08:26  2:09:27
# 7   1:40:59  1:46:40  1:50:55  1:52:22  1:58:10  2:04:07  2:08:58  2:09:51
# 8   1:39:12  1:44:15  1:47:58  1:49:13  1:54:16  1:59:39  2:03:59  2:04:46
# 9   1:39:13  1:44:15  1:48:00  1:49:18  1:54:27  1:59:50  2:04:09  2:04:56
# 10  1:40:16  1:45:33  1:49:27  1:50:49  1:56:10  2:01:43  2:05:56  2:06:43
# 11  1:39:13  1:44:15  1:47:59  1:49:18  1:54:29  1:59:54  2:04:19  2:05:07
# 12  1:39:14  1:44:16  1:47:59  1:49:18  1:54:34  2:00:21  2:05:07  2:05:59
# 13  1:43:37  1:49:32  1:54:02  1:55:36  2:01:45  2:08:13  2:13:33  2:14:30
# 14  1:42:12  1:47:22  1:51:06  1:52:21  1:57:27  2:02:52  2:07:04  2:07:50
# 15  1:42:46  1:48:00  1:51:50  1:53:14  1:58:23  2:03:51  2:08:18  2:09:07
#
#         26m      mar
# 0   2:09:33  2:10:39
# 1   2:07:11  2:08:13
# 2   2:08:13  2:09:20
# 3   2:07:32  2:08:36
# 4   2:09:37  2:10:45
# 5   2:23:41  2:25:06
# 6   2:16:21  2:17:50
# 7   2:15:39  2:16:58
# 8   2:09:58  2:11:11
# 9   2:10:11  2:11:18
# 10  2:11:51  2:12:57
# 11  2:10:23  2:11:34
# 12  2:11:45  2:13:09
# 13  2:20:38  2:21:55
# 14  2:13:00  2:14:10
# 15  2:14:28  2:15:38
#
# [16 rows x 53 columns]
