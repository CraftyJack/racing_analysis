# %% [markdown]
# # Setup

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import geopandas as gpd
import geopy
import numpy as np
import re
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import folium
from folium.plugins import FastMarkerCluster

# %% [markdown]
# # Import Data

# %% [markdown]
# ### Import the full finishers list

# %%
# bring in the csv
df = pd.read_csv("../00_data/raw_data/M2019_finishers.csv")
df.head()
# Out:
#                 name       geo_subregion country gender  age  bib  \
# 0      Michel Butter           Castricum     NLD      M   33    7
# 1  Geoffrey Kamworor  Kapchorwa District     KEN      M   26    3
# 2        Jack Rayner           Melbourne     AUS      M   23    9
# 3      Stephen Sambu          Tucson, AZ     USA      M   31   10
# 4         Jared Ward        Mapleton, UT     USA      M   31    6
#
#           team official_time pace_per_mile place_overall  ...      20m  \
# 0  New Balance       2:25:06         05:33            37  ...  1:43:56
# 1         NIKE       2:08:13         04:54             1  ...  1:38:59
# 2         NIKE       2:16:58         05:14            22  ...  1:40:59
# 3         NIKE       2:11:11         05:01             7  ...  1:39:12
# 4      Saucony       2:10:45         05:00             6  ...  1:39:13
#
#        21m      35k      22m      23m      24m      40k      25m      26m  \
# 0  1:50:22  1:55:04  1:56:42  2:03:26  2:10:32  2:16:06  2:17:07  2:23:41
# 1  1:44:07  1:47:34  1:48:44  1:53:20  1:57:59  2:01:48  2:02:30  2:07:11
# 2  1:46:40  1:50:55  1:52:22  1:58:10  2:04:07  2:08:58  2:09:51  2:15:39
# 3  1:44:15  1:47:58  1:49:13  1:54:16  1:59:39  2:03:59  2:04:46  2:09:58
# 4  1:44:15  1:47:57  1:49:12  1:54:16  1:59:35  2:03:47  2:04:34  2:09:37
#
#        mar
# 0  2:25:06
# 1  2:08:13
# 2  2:16:58
# 3  2:11:11
# 4  2:10:45
#
# [5 rows x 54 columns]

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53639 entries, 0 to 53638
# Data columns (total 54 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   53639 non-null  object
#  1   geo_subregion          53622 non-null  object
#  2   country                53639 non-null  object
#  3   gender                 53639 non-null  object
#  4   age                    53639 non-null  int64
#  5   bib                    53639 non-null  int64
#  6   team                   9282 non-null   object
#  7   official_time          53639 non-null  object
#  8   pace_per_mile          53639 non-null  object
#  9   place_overall          53639 non-null  object
#  10  place_gender           53639 non-null  object
#  11  age_group              53639 non-null  object
#  12  place_age-group        53639 non-null  object
#  13  country_group          53637 non-null  object
#  14  place_country          53639 non-null  object
#  15  place_age‐graded       53639 non-null  object
#  16  time_age‐graded        53639 non-null  object
#  17  percentage_age‐graded  53639 non-null  object
#  18  gun_time               53639 non-null  object
#  19  gun_place              53639 non-null  int64
#  20  3m                     53557 non-null  object
#  21  5k                     53594 non-null  object
#  22  4m                     53557 non-null  object
#  23  5m                     53585 non-null  object
#  24  6m                     53372 non-null  object
#  25  10k                    53558 non-null  object
#  26  7m                     53567 non-null  object
#  27  8m                     53598 non-null  object
#  28  9m                     53542 non-null  object
#  29  15k                    53550 non-null  object
#  30  10m                    53569 non-null  object
#  31  11m                    53547 non-null  object
#  32  12m                    53576 non-null  object
#  33  20k                    53447 non-null  object
#  34  13m                    53519 non-null  object
#  35  half                   53467 non-null  object
#  36  14m                    53532 non-null  object
#  37  15m                    53412 non-null  object
#  38  25k                    53517 non-null  object
#  39  16m                    53502 non-null  object
#  40  17m                    53548 non-null  object
#  41  18m                    53455 non-null  object
#  42  30k                    53338 non-null  object
#  43  19m                    53176 non-null  object
#  44  20m                    53150 non-null  object
#  45  21m                    53303 non-null  object
#  46  35k                    53379 non-null  object
#  47  22m                    53365 non-null  object
#  48  23m                    53135 non-null  object
#  49  24m                    53357 non-null  object
#  50  40k                    53202 non-null  object
#  51  25m                    53431 non-null  object
#  52  26m                    53344 non-null  object
#  53  mar                    53639 non-null  object
# dtypes: int64(3), object(51)
# memory usage: 22.1+ MB

# %% [markdown]
# ### Set up country coding assistant

# %%
class GroupMap:
    def __init__(self):
        self.data = {}
        
    # Based on discussion here: https://stackoverflow.com/questions/55892600/python-triplet-dictionary
    # Takes in a dictionary and creates an identical dictionary under each value in the original.
    # This provides a means to look up keys from values.
    # For example, {'a':'apple', 'b':'butter', 'c':'cocoa'} is stored as
    # {'apple':{'a':'apple', 'b':'butter', 'c':'cocoa'},
    # 'butter':{'a':'apple', 'b':'butter', 'c':'cocoa'},
    # 'cocoa':{'a':'apple', 'b':'butter', 'c':'cocoa'}}
    # so, self['butter'] returns {'a':'apple', 'b':'butter', 'c':'cocoa'}, 
    # and self['butter']['a'] returns 'apple'.
    # Be warned, newer entries overwrite older ones.

    def add(self, group):
        for thing in group.keys():
            self.data[group[thing]] = group

    def __getitem__(self, item):
        return self.data[item]

# %%
# Read in the conversion table from Wikipedia.
temp_df = pd.read_html('https://en.wikipedia.org/wiki/Comparison_of_alphabetic_country_codes')[0]    


# Tidy up the columm headings.
temp_df = temp_df[['Country', 'IOC', 'ISO']]
temp_df = temp_df.rename(columns={'IOC': 'IOC_code', 'ISO': 'ISO_code'})

# Drop the footnote citations from the table text.
citation_pattern = re.compile('\[[1-9][0-9]?\]')

temp_df['Country'] = temp_df['Country'].str.replace(citation_pattern,'')

# Drop the parenthetical notes from the table text. (Note the leading space.)
parenthetical_pattern = re.compile(' \(.+\)')

temp_df['Country'] = temp_df['Country'].str.replace(parenthetical_pattern,'')

# Reorder the comma separated entries.
temp_df['Country'] = temp_df['Country'].str.split(', ').apply(lambda x: ' '.join(x[::-1]))

# %%
country_code_trictionary = GroupMap()

thang = temp_df.to_dict('records')

for record in thang:
    country_code_trictionary.add(record)

# %%
def country_coder(country_query, desired_code):
    try:
        output = country_code_trictionary[country_query][desired_code]
        return output
    except:
        return None

# %% [markdown]
# # Data Prep and Cleaning

# %%
# First we need to correct some known errors in the data.

# Countries

# Some addresses for China (CHN) are mis-coded as 'CHI'.
df['country'] = df['country'].str.replace('CHI','CHN')

# Some addresses for Romania (ROU) are mis-coded as 'ROM'.
df['country'] = df['country'].str.replace('ROM','ROU')

# Some addresses for the Democratic Republic of the Congo (COD) are mis-coded as 'Dem'
df['country'] = df['country'].str.replace('Dem','COD')

# One address for the USA (USA) is mis-coded as 'Sai'
df['country'] = df['country'].str.replace('Sai','USA')

# Geo_subregions

# The periods in 'L.I.C.' generate errors.
df['geo_subregion'] = df['geo_subregion'].str.replace('L.I.C.','Long Island City')

# %%
# How many countries are represented?
len(df['country'].unique())
# Out:
# 137

# %%
# Now convert the country abbreviations to the expanded country names.
# The geocoder is a lot more successful with expanded names.

df['long_country'] = df['country'].apply(lambda country: country_coder(country, 'Country'))

# %%
# How many records were not expandable?

df.long_country.isnull().sum()
# Out:
# 0

# %% [markdown]
# # Geocoding

# %% [markdown]
# ### Pull in known addresses

# %%
address_list_df = pd.read_csv("address_cache.csv")
address_list_df.head()
# Out:
#                       address  \
# 0       Castricum Netherlands
# 1    Kapchorwa District Kenya
# 2         Melbourne Australia
# 3    Tucson, AZ United States
# 4  Mapleton, UT United States
#
#                                         full_address  \
# 0                Castricum, Noord-Holland, Nederland
# 1  District Farm Institute, Sironko Kapchorwa Roa...
# 2  Melbourne, City of Melbourne, Victoria, 3000, ...
# 3        Tucson, Pima County, Arizona, United States
# 4  Mapleton, Utah County, Utah, 84664, United States
#
#                                   location
# 0  (52.558830549999996, 4.639675526200153)
# 1                  (1.2992853, 34.3193213)
# 2               (-37.8142176, 144.9631608)
# 3               (32.2228765, -110.9748477)
# 4               (40.1302338, -111.5785281)

# %% [markdown]
# ### Merge known addresses to the finisher data

# %%
# construct an 'address' for geocoding purposes
df['address'] = df['geo_subregion'] + " " + df['long_country']

# Merge with the cached address list.
df = df.merge(address_list_df, how='left', on='address')

# %%
df.head()
# Out:
#                 name       geo_subregion country gender  age  bib  \
# 0      Michel Butter           Castricum     NLD      M   33    7
# 1  Geoffrey Kamworor  Kapchorwa District     KEN      M   26    3
# 2        Jack Rayner           Melbourne     AUS      M   23    9
# 3      Stephen Sambu          Tucson, AZ     USA      M   31   10
# 4         Jared Ward        Mapleton, UT     USA      M   31    6
#
#           team official_time pace_per_mile place_overall  ...      23m  \
# 0  New Balance       2:25:06         05:33            37  ...  2:03:26
# 1         NIKE       2:08:13         04:54             1  ...  1:53:20
# 2         NIKE       2:16:58         05:14            22  ...  1:58:10
# 3         NIKE       2:11:11         05:01             7  ...  1:54:16
# 4      Saucony       2:10:45         05:00             6  ...  1:54:16
#
#        24m      40k      25m      26m      mar   long_country  \
# 0  2:10:32  2:16:06  2:17:07  2:23:41  2:25:06    Netherlands
# 1  1:57:59  2:01:48  2:02:30  2:07:11  2:08:13          Kenya
# 2  2:04:07  2:08:58  2:09:51  2:15:39  2:16:58      Australia
# 3  1:59:39  2:03:59  2:04:46  2:09:58  2:11:11  United States
# 4  1:59:35  2:03:47  2:04:34  2:09:37  2:10:45  United States
#
#                       address  \
# 0       Castricum Netherlands
# 1    Kapchorwa District Kenya
# 2         Melbourne Australia
# 3    Tucson, AZ United States
# 4  Mapleton, UT United States
#
#                                         full_address  \
# 0                Castricum, Noord-Holland, Nederland
# 1  District Farm Institute, Sironko Kapchorwa Roa...
# 2  Melbourne, City of Melbourne, Victoria, 3000, ...
# 3        Tucson, Pima County, Arizona, United States
# 4  Mapleton, Utah County, Utah, 84664, United States
#
#                                   location
# 0  (52.558830549999996, 4.639675526200153)
# 1                  (1.2992853, 34.3193213)
# 2               (-37.8142176, 144.9631608)
# 3               (32.2228765, -110.9748477)
# 4               (40.1302338, -111.5785281)
#
# [5 rows x 58 columns]

# %%
df['location'][0].split(', ')[1]
# Out:
# '4.639675526200153)'

# %%
# How many records still need geocoding?

df.location.isnull().sum()
# Out:
# 694

# %% [markdown]
# ### Create an address list for geocoding

# %%
# build a list of unique addresses so that we can spend less time making geocode requests.
address_list = df.loc[df['location'].isnull(), 'address'].unique()
len(address_list)
# Out:
# 535

# %%
address_list
# Out:
# array(['Kapkitony Kenya', "New Taipei City People's Republic of China",
#        'O Fallon, MO United States', 'Chesitek Kenya', nan,
#        "Hsinchu City People's Republic of China", 'Fpo, AP United States',
#        'København Sv Denmark', "Miaoli County People's Republic of China",
#        'Loenen Gld Netherlands', 'Seoul, Mapo-gu United States',
#        'Nakorn Ratchasima Thailand', 'North Plainfiel, NJ United States',
#        'Steeplechase Corner Costa Rica', 'Rocca D Evandro Italy',
#        'Segataya-Ku Japan', "Kibbutz Mishmar Ha'emek Israel",
#        'Fort Lauderdalefort Lauderdale, FL United States',
#        'New York City Uzbekistan', 'Castelldfels Spain',
#        'Saint Pierre D Oleron France',
#        'La Plata, Buenos aires United States', 'Zargoza Spain',
#        'Tavagnacco Ud Italy', 'Ballerup, Denmark United States',
#        'Amsterdam-Zuid Antigua and Barbuda', 'Maspalmos Spain',
#        'Seeblick Ot Wassersuppe Germany',
#        'Buenos Aires Argentina, Martinez United States',
#        'Louisville Dominican Republic', 'Elmont, Bogota dc United States',
#        'West Albury, New South Wales United States',
#        'Северо-Западный Административный Окру Russian Federation',
#        'Barry D Islemade France', 'Bezirk Spandau Germany',
#        'San Esteban De Sasroviras Spain', 'New Territory Hong Kong',
#        'Ivanteevka Russian Federation',
#        'Tres Arroyos, Buenos aires United States',
#        "Pudong New District People's Republic of China",
#        'Amsterdam-Oost Antigua and Barbuda', 'Ireland (Irl) Ireland',
#        'Mc Farland, WI United States', 'Apo, AP United States',
#        'Madrid, Comunidad de Madrid United States',
#        'Bleanau Ffestiniog United Kingdom', 'Helsinborg Sweden',
#        'Sant Antonino Di Susa Italy', 'Bronx Ireland',
#        'Kirk Michael Iceland',
#        "Wanjiang District, Dongguan, People's Republic of China",
#        'Huntington Stat, NY United States',
#        'Saint-Honore-De-Chicoutimi Canada',
#        'Glen Huntly, Victoria United States',
#        "Nanjingc People's Republic of China", 'Buenos Bires Argentina',
#        'Alamosa, Bratislavský kraj United States', 'Singpapore Singapore',
#        'Barre, Vaud United States', 'Coalc Australia',
#        'Neustift Im Mk. Austria', 'Barre, IllinoisVaud United States',
#        "Taichung People's Republic of China", 'Carnikavas Nov. Latvia',
#        'Palos Verdes Peninsula, CA United States',
#        'Ashby, Buenos aires United States',
#        'Stadtbezirke Ix Essen Germany', 'Tsuen Wan Australia',
#        'Bjärred United Kingdom', 'Junin, Buenos aires United States',
#        'Haarlem, Noord Holland United States',
#        "New Taipei People's Republic of China",
#        'Dubai, uae United States', 'Vincennesvincennes France',
#        'Fotlandsvaag Norway', 'Stetten Akm Germany',
#        'Hattorf-Heiligendorf Germany', 'Urb. San Luis, Caracas Venezuela',
#        'Saint Isnier France', 'Lonevaag Norway',
#        'São Paulo - Brazil Brazil', 'Kitakahei-Cho Japan',
#        'Klampenborg, Klampenborg United States', 'Vsters Sweden',
#        'Saline Vanuatu', 'Wassenaar Antigua and Barbuda',
#        'Blaricum Antigua and Barbuda',
#        'Croton On Hudso, NY United States',
#        'Minneapolis, Jonkopings lan United States',
#        "Hsinchu People's Republic of China", 'Kristansand Norway',
#        'Hannaton Israel', 'Hastings On Hud, NY United States',
#        'Briarcliff Mano, NY United States', 'Villette D Anthon France',
#        'La Chaux-De-Fonds Liechtenstein',
#        'Norwalk, ConnecticutNorwalk United States',
#        'Haupauge, NY United States',
#        'Bezirk Tempelhof-Schöneberg Germany', 'Adachiku Japan',
#        'Le Cannet, Alpes Maritimes United States',
#        'Great Nck Plz, NY United States', 'Townsead, DE United States',
#        'Long Island Cit, NY United States',
#        'South Pomfret, South Australia United States',
#        'Torslanda, Torslanda United States', 'Reihertshausen Germany',
#        'Campton, Victoria United States',
#        'Santiago De Los Caballeros Republica Dominicana Dominican Republic',
#        "Pukouqu People's Republic of China", 'South Coast Metro Austria',
#        'Osteras, Osteras United States', 'Neukirchen Bei Lambch Austria',
#        'Canberra, ArkansasACT United States',
#        'Nr Bradford United Kingdom', 'Liege, Liege United States',
#        "Hsinchu County People's Republic of China",
#        'Vrsac, Vrsac United States',
#        "Kaohsiung City People's Republic of China", 'Bangkoknoi Thailand',
#        'Hockessin, DE United States',
#        'Jersey City, New JerseJ United States', 'Belo Horizone Brazil',
#        "Kaohsiung People's Republic of China", 'Kecway Halim Indonesia',
#        'Boksburg, Gauteng United States', 'Hampton, Vic United States',
#        'Prishtina, Kosovo United States', 'Bouskoura France',
#        'Hamme Denmark', 'Khuder Soum Mongolia', 'Saint-Herblains France',
#        'New York, État de New York United States', 'Vitacura Chad',
#        'Johannesburg, Missouriteng United States',
#        'Distrito Nacional, Santo Domingo United States',
#        'East Waterboro, QLD United States',
#        "Guishan Dist. People's Republic of China",
#        'Kyoto Mukoucity Japan', 'New York, New YorkNY United States',
#        "Kaohsung People's Republic of China",
#        'Ulaanbaatar, Bayanzurkh district United States',
#        "Taichung City People's Republic of China",
#        'Neufgrange French Polynesia', 'Pratovecchiostia Italy',
#        'Northampton, FloridaAuckland United States',
#        'Frederiksberg, Denmark United States',
#        'Bezirk Steglitz-Zehlendorf Germany',
#        'Avant, Harju mk United States', 'Elmhurst Thailand',
#        'Yangon Burkina Faso', 'Tokorozawashi Japan', 'Mahammedia Morocco',
#        'Staten Island Eswatini', 'Hastings-On-Hud, NY United States',
#        'Wakefield, Antwerp United States',
#        'Beersel, Beersel United States',
#        'Blue Springs, italy United States',
#        "Fuoshan People's Republic of China",
#        'Knokke, West-Vlaanderen United States', 'Commungny Switzerland',
#        'Republica Dominicada Dominican Republic',
#        'Buenos Aires Antigua and Barbuda', 'Ampher Meung Thailand',
#        'Celje, Slovenija United States',
#        'North Brunswick, NJ United States',
#        "Sanxia Dist., New Taipei City People's Republic of China",
#        'Tannanarivo Madagascar', 'Sant Vicen Dels Horts Spain',
#        'New Rochelle, New YorkNY United States',
#        'Provo, UtahT United States', 'San Pedro, Garza Garcia Mexico',
#        'Bezirk Charlottenburg-Wilmersdorf Germany',
#        'Isle Of Harris United Kingdom',
#        'Newark Nj, Nova JerseyNewark United States',
#        'Foligno, Italia/perugia United States', 'Malbourne Australia',
#        'Corroy Le Grand, Corroy le Grand United States',
#        'Vila Mascote Brazil', 'Guatemala, Ciudad Guatemala United States',
#        'Illnau-Effretikon Liechtenstein', 'Chontenay Sur Conie France',
#        'Leiderdorp Antigua and Barbuda',
#        'Amsterdam-West Antigua and Barbuda', 'Monrterrey Mexico',
#        'Luthvle Timon, MD United States', 'Fukuishi Japan',
#        'Cassano D. Adda Italy', 'Foligno, Perugia United States',
#        'Schreventeich - Hasseldieksdamm De Schreventeich Germany',
#        'St Pierre De Clage Switzerland', 'Fotlandsvg Norway',
#        'Beograd, Cukarica United States',
#        'Ljubljana, Slovenia United States', 'Bouskoura Casablanca France',
#        'Vaerloese, Hareskovby United States',
#        "Eyguières, Provence-Alpes-Côte d'Azur United States",
#        'Arue - Tahiti French Polynesia', 'La Mezieze France',
#        'Bezirk Moabit Germany', 'Hoofddorp Antigua and Barbuda',
#        'New Market, MarylandMD United States', 'Bangkokyai Thailand',
#        'Gyqr Hungary', 'Udine, Friuli-Venezia Giulia United States',
#        'Aarsta Sweden', 'Dedham, New South Wales United States',
#        'Bondi Junction, NSW United States', 'Londond United Kingdom',
#        'Cape Town, western cape United States',
#        'Guarenas, Miranda United States', 'Canton, Gauteng United States',
#        'Locust Grove Netherlands', 'Etrembier France',
#        'Alloway, western cape United States',
#        'The Hague Antigua and Barbuda', 'Badin, Madrid United States',
#        'Rijswijk Antigua and Barbuda', 'Steffisburg, Bern United States',
#        'Saveneta Aruba', 'Bnigen Bei Interlaken Switzerland',
#        'Lyonyon France', 'Northeast Carrollton Switzerland',
#        'Romaroma Italy', 'Villigen, Aargau United States',
#        "Zhubei City, Hsinchu County People's Republic of China",
#        'San Mateo Tlaltenango, Ciudad de MéxicoF United States',
#        'Empoli, firenze United States', 'Ruda (Ud) Italy',
#        'San Pedro, Garza Garcia. Nl Mexico',
#        'Oslo, Akershus United States', 'Medelllin Colombia',
#        'Neuilly-Sur-Seineeuilly Sur Seine France',
#        'Croudace Bay, New South Wales United States', 'Bangpli Thailand',
#        'San Fancisco 2 Ríos Costa Rica', 'Amsterdam Antigua and Barbuda',
#        'Hasbrouck Heigh, NJ United States', 'Bfpo2 United Kingdom',
#        'Humlebaek, Denmark United States',
#        'Chácara Santo Antônio (Zona Sul) Brazil',
#        'Yorktown Height, NY United States',
#        'Sunnysisde, NY United States',
#        'San Pedro Sula, cortes United States',
#        'New Millport, Bromma United States', 'Omersviller France',
#        'La Tahona Golf Club Uruguay', 'Chiswicklondon United Kingdom',
#        'Bougueanis France', "Moscow Democratic People's Rep. Korea",
#        'Comune Di Castelfranco Emilia Italy', 'Ashton Heights Austria',
#        'Whangarei, northland United States',
#        'Saint Louis, Hessen United States',
#        'Peterboroughbaston United Kingdom', 'Hamburg Andorra',
#        'Drancy Antarctica', 'Bangsaothong Thailand',
#        'Floral Park, Colombia United States',
#        'Uniondale, riyadh United States',
#        'Las Palmas - Islas Canarias Spain',
#        'Bienrode-Waggum-Bevenrode Germany',
#        'Bronx, État de New York United States',
#        'Te Awamutu, Waikato United States',
#        'Nara-Shi, Nara-Ken United States', 'Snaoya Norway',
#        'Rambouilllet France',
#        'Condomínio Chácaras Do Alto Da Nova Campinas Brazil',
#        'Bezirk Treptow-Köpenick Germany', 'Johanneburg South Africa',
#        'Duncanville, Paris United States', 'Behren Les Forbach Germany',
#        'Fushe Kosove, Kosovo United States',
#        'Charles City, Tijuana United States',
#        'Kuesnacht, Zurich United States', 'Möhringenstuttgart Germany',
#        'Mid-Level Hong Kong', 'Hamburg-Nordhamburg Germany',
#        'Rowe, Baerum United States', 'Waldenburg Sweden',
#        'Astoria, New YorkNY United States', 'New Yor, NY United States',
#        'Great Neck Italy', 'Greenvale, Vic United States',
#        'Tananarivo Madagascar', 'Odrathzeim France',
#        'Allen, Ile-de-France United States',
#        'Berhren Les Forbach Germany',
#        'Nagoya-Shi, Aichi-Ken United States',
#        'Ituzaingo, Buenos aires United States', 'Russee - Hammer Germany',
#        'Las Condes, Santiago Metropolitan Region United States',
#        "Shagnhai People's Republic of China",
#        'Oakland, CaliforniaCA United States',
#        'Saint Syr Sur Rhone France', 'Gany Tikva Israel',
#        'Aosta Italy Italy', 'Residencial Seis (Alphaville) Brazil',
#        'Prishtina, Kosova United States', 'St-Sauveur-Des-Monts Canada',
#        'Hong Kong, New Territories United States',
#        'Lillehammer, Norway United States', 'Bronbron France',
#        'København Nv Denmark', 'Reykjavík, Seltjarnarnes United States',
#        'Capital Federal, Ciudad de BUenos Aires United States',
#        'Capital, Santiago del Estero United States', 'Clazac France',
#        'Leciestershire United Kingdom',
#        'Bradfield Reading United Kingdom',
#        'Portwashington, NY United States',
#        'Pt Pleas Bch, NJ United States', 'Wimbledon Venezuela',
#        'Mexico City Mayotte', 'Naarden Antigua and Barbuda',
#        'Brighton East, Victoria United States',
#        'New Kensington, PennsylvaniaPa United States',
#        'Clayton, Italia United States', 'Stafford, England United States',
#        'Boston, MassachusettsB United States',
#        'Willemstad Antigua and Barbuda', 'Panamam Panama',
#        'Seftigen Liechtenstein', 'Clearwater Bay Hong Kong',
#        'Dorchestr Ctr, MA United States', 'Miami Beach, NY United States',
#        'South Plainfiel, NJ United States',
#        'Northampton, Auckland United States', 'Fpo, AE United States',
#        'South Windham South Africa', 'Glasser, NJ United States',
#        'Hamilton, Waikato United States', 'Kirtyat Ono Israel',
#        'Deventer Antigua and Barbuda', 'Quto Ecuador',
#        'Springfield Grd, NY United States',
#        'Neustadt Am Rübenbergeneustadt Germany',
#        'Provincetownemaastricht Netherlands', 'Guthenburg Sweden',
#        'Bezirk Bergedorf  Hamburg Germany',
#        'Antwerpen, Anterpen United States', 'Guatema Guatemala',
#        'Sydney, New South Wales United States', 'Linkping Sweden',
#        'Omalley, ACT United States', 'Bezirk Reinickendorf Germany',
#        'Paducah, SORIA United States', 'Piton Saint-Leu France',
#        'Mc Kean, PA United States', 'Miramont D Astarac France',
#        'Plainwell, Maine et Loire United States',
#        'Ecublens Liechtenstein', 'Hopewell Juncti, NY United States',
#        "Ｈｏｎｇ\u3000Ｋｏｎｇ People's Republic of China", 'Buccinaso Italy',
#        'Sant Petesburg Russian Federation', 'Castroville Uzbekistan',
#        "Shangahai People's Republic of China", 'Casablaca Morocco',
#        'Pq Res Aquarius Brazil', 'Ceby City Philippines',
#        'Untergiesing-Harlachingmnchen Germany', 'Skopje Norway',
#        'Kew Gardens Hil, NY United States',
#        'N. Valley Strea, NY United States', 'Sparrta, NJ United States',
#        'Bellevue Hill, NSW United States',
#        'Eltham, Victoria United States', 'Minot, Gauteng United States',
#        'Grand Cayman Canada', 'Dorforf Liechtenstein',
#        'Longuiville Australia', 'Nes Ziyona Israel',
#        'Chicago, Illinois [IL] United States',
#        'East Dover, Famagusta United States',
#        'Kroonstad, Free state United States',
#        'Geraardsbergen, Oost Vlaanderen United States',
#        'General Pico, La Pampa, Argentina Argentina',
#        'Apeldoorn Noord-Oost Netherlands',
#        'Manahawkin, Bolivar United States',
#        'Bologna, Emilia-Romagna United States',
#        'New York, Thailand United States',
#        'Sebago Lake, QLD United States', 'Margherita Di Savoia Jamaica',
#        'Cumming Italy', 'Herewegwijk En Helpman Netherlands',
#        'New Rochelle, New orkN United States', 'Bladelbladel Netherlands',
#        'Dublin, Dun Laoghaire United States', 'S.M. De Tucuman Argentina',
#        'Stadtbezirke Iv Germany',
#        'U.S Virgin Island, St. Thomas United States',
#        'Brain Sur L Authion France',
#        'Longs, South CarolinaJeff Leake United States',
#        'Melbounre Australia', 'Salles D Angles France',
#        'Montugny Le Bretonneux France', 'Columbia, Varese United States',
#        'Numansdorp Antigua and Barbuda',
#        'Princeton Jct, NJ United States', 'Middx United Kingdom',
#        'Vandoncourt, FRANCE United States',
#        'Comune Di Castelfranco Veneto Italy',
#        'Sparreholm, Södermanlands län United States',
#        'Dardillydardilly France',
#        'Sao Bernardo Do Campo, São Paulo United States',
#        'Barnegat, western cape United States',
#        'Longe Ville Les Metz France', 'Mc Gregor, TX United States',
#        'Bezirk Neukölln Germany',
#        'Rancho Cordova, CaliforniaAndrei United States',
#        'Manhattan, État de New York United States', 'Aracaju Botswana',
#        'Raynes Arkp United Kingdom', 'Rittenhouse Square Belgium',
#        'Erlangen, Germany United States', 'Higasikanbara Japan',
#        'Foxboro, New YorkNSW United States',
#        'San Francisco, Ile de France United States',
#        'Saint Romain Au Mont D Or France',
#        'Briar Hill, Victoria United States',
#        'Hong Kong, CHINA United States',
#        'Nottingham, KwaZulu Natal United States',
#        'Eindhoven Antigua and Barbuda', 'Kng Of Prussa, PA United States',
#        'Campinas, Sao Paulo United States', 'Hellerup, NA United States',
#        'Rosino Bulgaria', 'North Chatham, Antwerpen United States',
#        'Johannesburg, Gauteng United States',
#        'De Veenhoop Antigua and Barbuda', 'Hertzelia Israel',
#        'Wijk Bij Duurstede Antigua and Barbuda',
#        "Hatdtan District People's Republic of China",
#        "Taiper City People's Republic of China",
#        'South Ozone Par, NY United States', 'Setonai-Shi Japan',
#        'Aran-Villette/Grandvaux Liechtenstein', 'Lima18 Peru',
#        'Frederiksberg, Frederiksberg United States',
#        'Quezon City, Manila United States',
#        'Arnada, Metro Manila United States', 'Seuzach Liechtenstein',
#        'Rockville Centr, NY United States', 'New Yurk, NY United States',
#        'Prverenges Switzerland', "Beijjing People's Republic of China",
#        'Hainichen/Ot Bockendorf Germany',
#        'Chatuchak, Bangkok United States', 'Tucson Germany',
#        'Mesa Norway', 'Finglas North, County Dublin United States',
#        'Bahia Blanca, Buenos aires United States',
#        'Darfo Baorio Terme Italy', 'Barrington, Vic United States',
#        'Saikung Hong Kong', 'Palmyra, Western Australia United States',
#        'East Freetown Italy', 'Apo, Troms United States',
#        'New Territories, Sham Tseng United States', 'Mimato-Ku Japan',
#        'Bandolbandol France', 'Bezirk Marzahn-Hellersdorf Germany',
#        'Oakleigh, Victoria United States',
#        'Caba Bs As Argentina Argentina',
#        'Hvittingfoss, Norway United States',
#        'Queens, New York [NY] United States',
#        'Whitlwy Bay United Kingdom',
#        'Gam, Ciudad de Mexico United States',
#        'St.Peteresburg Russian Federation',
#        'Punaauia - Tahiti French Polynesia',
#        'Cabo Rojo Northern Mariana Islands',
#        'Weymouth, Gauteng United States',
#        'Bezirk Friedrichshain-Kreuzberg Germany',
#        'Brooklyln, NY United States', 'Gratta Terme (Fc) Italy',
#        'Vessy, Geneve United States', 'Bangkok, Bangkok United States',
#        'San Fracisco De Campeche Mexico',
#        "Nr Bishop's Stortford United Kingdom",
#        'Severna Parkseverna Park, MD United States',
#        'Rignano Sul Arno Italy', 'Kasugashi Japan',
#        'San Antonio, TexasTx United States', 'Beratzhausen Aruba',
#        'Tampa, Nordrhein-Westfalen United States',
#        'Northampton, Auckland City United States', 'Guayllabamna Ecuador',
#        'Yuenlong Hong Kong',
#        'Washington, New JerseyWashington United States',
#        'Kopavogi, Iceland United States', 'Salzano Venice Italy',
#        'Stavanger, Hafrsfjord United States', 'Eagleville Italy',
#        'Palmerston North, MANAWATU United States',
#        'Bellingham, Norway United States', 'Cfar Bialik Israel',
#        'Beek - Ubergen Netherlands', 'Monclair, NJ United States',
#        'Mooloolaba, Queensland United States',
#        "Banqiao Dist People's Republic of China",
#        'Ikoyi, Lagos United States',
#        'San Clemente, Californiac United States',
#        'Durham, England United States', 'Nøtterøy, Norway United States',
#        'Guayaqsuil Ecuador', 'Saint Louis, MissouriMO United States',
#        'Esbo, Finland United States', 'Kualalumpur Malaysia',
#        'Apo, Oost Vlaanderen United States',
#        'Worcester, Buenos aires United States',
#        'Framingham, Metro Manila United States',
#        'Bodegraven, Holandia Południowa United States',
#        'Fort Worth, UNITED STATES United States',
#        'Amphoe Dan Khun Thot Thailand', 'Hungtington, NY United States',
#        'Taguig City, Metro Manila United States', 'Thonburi Thailand',
#        'Wishart Australia', 'Oadby United Kingdom', 'Pollestres France',
#        "Clearwater Bay, Sai Kung People's Republic of China",
#        'Cossato, Biella United States',
#        'Manchester, Connecticutt United States',
#        'Cumberlnd Ctr, ME United States', 'Alpharetta Indonesia',
#        'Las Pinas, Metro Manila United States',
#        'Mc Keesport, PA United States', 'Raadal Norway',
#        'Acton, NCR United States', 'Huiquang Thailand',
#        'Rabun Gap, GA United States', 'Fukuokasi Japan',
#        'Basidlon United Kingdom', 'Argyull United Kingdom'], dtype=object)

# %%
query_df = pd.DataFrame(address_list)
query_df.to_csv('..00_data/geodata/list.csv')

# %% [markdown]
# ### Commence geocoding

# %%
# set up the geocoder

locator = Nominatim(user_agent="myGeocoder")
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# %%
location_dict = {}
problem_locations = []
counter = 0
goal = len(address_list)

for address in address_list:
    counter += 1
    try:
        location_result = geocode(address)
        if location_result == None:
            problem_locations.append(address)
            print("{} of {}. No location found for {}.".format(counter, goal, address))
        else:
            location_dict[address] = geocode(address)
            print("{} of {}. Found location for {}.".format(counter, goal, address))
    except:
        problem_locations.append(address)
        print("{} of {}. No location found for {}.".format(counter, goal, address))
# Out:
# 1 of 535. No location found for Kapkitony Kenya.
# 2 of 535. No location found for New Taipei City People's Republic of China.
# 3 of 535. No location found for O Fallon, MO United States.
# 4 of 535. No location found for Chesitek Kenya.
# 5 of 535. Found location for nan.
# 6 of 535. No location found for Hsinchu City People's Republic of China.
# 7 of 535. No location found for Fpo, AP United States.
# 8 of 535. No location found for København Sv Denmark.
# 9 of 535. No location found for Miaoli County People's Republic of China.
# 10 of 535. No location found for Loenen Gld Netherlands.
# 11 of 535. No location found for Seoul, Mapo-gu United States.
# 12 of 535. No location found for Nakorn Ratchasima Thailand.
# 13 of 535. No location found for North Plainfiel, NJ United States.
# 14 of 535. No location found for Steeplechase Corner Costa Rica.
# 15 of 535. No location found for Rocca D Evandro Italy.
# 16 of 535. No location found for Segataya-Ku Japan.
# 17 of 535. No location found for Kibbutz Mishmar Ha'emek Israel.
# 18 of 535. No location found for Fort Lauderdalefort Lauderdale, FL United States.
# 19 of 535. No location found for New York City Uzbekistan.
# 20 of 535. No location found for Castelldfels Spain.
# 21 of 535. No location found for Saint Pierre D Oleron France.
# 22 of 535. No location found for La Plata, Buenos aires United States.
# 23 of 535. No location found for Zargoza Spain.
# 24 of 535. No location found for Tavagnacco Ud Italy.
# 527 of 535. No location found for Las Pinas, Metro Manila United States.
# 528 of 535. No location found for Mc Keesport, PA United States.
# 529 of 535. No location found for Raadal Norway.
# 530 of 535. No location found for Acton, NCR United States.
# 531 of 535. No location found for Huiquang Thailand.
# 532 of 535. No location found for Rabun Gap, GA United States.
# 533 of 535. No location found for Fukuokasi Japan.
# 534 of 535. No location found for Basidlon United Kingdom.
# 535 of 535. No location found for Argyull United Kingdom.

# %%
len(problem_locations)
# Out:
# 530

# %%
problem_locations_df = pd.DataFrame(problem_locations)
problem_locations_df.to_csv('..00_data/geodata/problem_addresses.csv')

# %%
df['location'] = df['address'].apply(lambda address: location_dict[address] if address in location_dict else None)
df['latitude'] = df['location'].apply(lambda loc: loc.latitude if loc else None)
df['longitude'] = df['location'].apply(lambda loc: loc.longitude if loc else None)

# %%
df.location.isnull().sum()
# Out:
# 53618

# %%
df['full_address'][0].loc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-b8627965c1d6> in <module>
# ----> 1 df['full_address'][0].loc
#
# AttributeError: 'str' object has no attribute 'loc'

# %%
address_cache_df = pd.DataFrame.from_dict(location_dict)
address_cache_df = address_cache_df.transpose()

# %%
address_cache_df

# %%
address_cache_df = address_cache_df.reset_index()
address_cache_df.rename(columns={'index': 'address', 0: 'full_address', 1: 'location'}, inplace=True)

# %%
address_cache_df

# %%
# define the path and name for the output file
output_csv = "..00_data/geodata/address_cache.csv"

import csv

# We want to match the order of columns if we are appending new entries to an existing file.
### Because we are using a dictionary to capture the race results, and of the way dictionaries are ordered,
### It is possible for different scraping runs to attempt to order the columns differently.
### That would be confusing, so we force whatever order was established in the first run.
### (The bottom line is that it would really be a good idea to use a database here instead.)

# Try to read the header from the existing file. If they exist, match the column order.
try:
    with open(output_csv, 'r', encoding="utf-8") as f:
        reader = csv.reader(f)
        header_list = next(reader)
        # It is possible to be missing columns, so check to see if we have everything.
        for x in header_list:
            if x not in address_cache_df.columns:
                address_cache_df[x] = ''
        address_cache_df = address_cache_df[header_list]
# If we weren't able to open the file, we are going to create one from scratch.
except:
    print(f"{output_csv} does not exist, so I'll create it!")

# This either creates the file, or appends to it without headers. We already took steps to make sure
# the columns in finishers_df match the headers (if they exist).
with open(output_csv, 'a', encoding="utf-8") as f:
    address_cache_df.to_csv(f, header=f.tell()==0, index = False, line_terminator = '\n')

# %%
mapping_df = df[pd.notnull(df["latitude"])]

# %%
mapping_df.info(verbose = True)

# %%
df.info(verbose=True)

# %%
map1 = folium.Map(
    location=[40.7128, -74.0060],
    tiles='cartodbpositron',
    zoom_start=12,
)

# %%
mapping_df.apply(lambda row:folium.CircleMarker(location=[row["latitude"], row["longitude"]]).add_to(map1), axis=1)
map1

# %%
map1.save("map7.html")

# %%
folium_map = folium.Map(location=[40.7128, -74.0060],
                        zoom_start=12,
                        tiles='cartodbpositron')


FastMarkerCluster(data=list(zip(mapping_df['latitude'].values, mapping_df['longitude'].values))).add_to(folium_map)
folium.LayerControl().add_to(folium_map)
folium_map

# %%
folium_map.save("map8.html")
